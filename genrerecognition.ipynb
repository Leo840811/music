# %% [markdown]
# # 取出特徵csv

# %% [markdown]
# ## 定義函式

# %%
import librosa
import numpy as np
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import time


def extract_feature(path):
    id = 1  # Song ID
    
    # 給一個 DataFrame表格變數
    feature_set = pd.DataFrame()  
    
    # 給個別的特徵一個 Series欄位變數
    songname_vector = pd.Series(dtype='float64')
    tempo_vector = pd.Series(dtype='float64')
    total_beats = pd.Series(dtype='float64')
    average_beats = pd.Series(dtype='float64')
    chroma_stft_mean = pd.Series(dtype='float64')
    chroma_stft_std = pd.Series(dtype='float64')
    chroma_stft_var = pd.Series(dtype='float64')
    chroma_cq_mean = pd.Series(dtype='float64')
    chroma_cq_std = pd.Series(dtype='float64')
    chroma_cq_var = pd.Series(dtype='float64')
    chroma_cens_mean = pd.Series(dtype='float64')
    chroma_cens_std = pd.Series(dtype='float64')
    chroma_cens_var = pd.Series(dtype='float64')
    mel_mean = pd.Series(dtype='float64')
    mel_std = pd.Series(dtype='float64')
    mel_var = pd.Series(dtype='float64')
    
#     mfcc_mean = pd.Series()
#     mfcc_std = pd.Series()
#     mfcc_var = pd.Series()
#     mfcc_delta_mean = pd.Series()
#     mfcc_delta_std = pd.Series()
#     mfcc_delta_var = pd.Series()

    mfcc1_mean = pd.Series(dtype='float64')
    mfcc2_mean = pd.Series(dtype='float64')
    mfcc3_mean = pd.Series(dtype='float64')
    mfcc4_mean = pd.Series(dtype='float64')
    mfcc5_mean = pd.Series(dtype='float64')
    mfcc6_mean = pd.Series(dtype='float64')
    mfcc7_mean = pd.Series(dtype='float64')
    mfcc8_mean = pd.Series(dtype='float64')
    mfcc9_mean = pd.Series(dtype='float64')
    mfcc10_mean = pd.Series(dtype='float64')
    mfcc11_mean = pd.Series(dtype='float64')
    mfcc12_mean = pd.Series(dtype='float64')
    mfcc13_mean = pd.Series(dtype='float64')
    mfcc14_mean = pd.Series(dtype='float64')
    mfcc15_mean = pd.Series(dtype='float64')
    mfcc16_mean = pd.Series(dtype='float64')
    mfcc17_mean = pd.Series(dtype='float64')
    mfcc18_mean = pd.Series(dtype='float64')
    mfcc19_mean = pd.Series(dtype='float64')
    mfcc20_mean = pd.Series(dtype='float64')
    
    mfcc1_std = pd.Series(dtype='float64')
    mfcc2_std = pd.Series(dtype='float64')
    mfcc3_std = pd.Series(dtype='float64')
    mfcc4_std = pd.Series(dtype='float64')
    mfcc5_std = pd.Series(dtype='float64')
    mfcc6_std = pd.Series(dtype='float64')
    mfcc7_std = pd.Series(dtype='float64')
    mfcc8_std = pd.Series(dtype='float64')
    mfcc9_std = pd.Series(dtype='float64')
    mfcc10_std = pd.Series(dtype='float64')
    mfcc11_std = pd.Series(dtype='float64')
    mfcc12_std = pd.Series(dtype='float64')
    mfcc13_std = pd.Series(dtype='float64')
    mfcc14_std = pd.Series(dtype='float64')
    mfcc15_std = pd.Series(dtype='float64')
    mfcc16_std = pd.Series(dtype='float64')
    mfcc17_std = pd.Series(dtype='float64')
    mfcc18_std = pd.Series(dtype='float64')
    mfcc19_std = pd.Series(dtype='float64')
    mfcc20_std = pd.Series(dtype='float64')

    mfcc1_var = pd.Series(dtype='float64')
    mfcc2_var = pd.Series(dtype='float64')
    mfcc3_var = pd.Series(dtype='float64')
    mfcc4_var = pd.Series(dtype='float64')
    mfcc5_var = pd.Series(dtype='float64')
    mfcc6_var = pd.Series(dtype='float64')
    mfcc7_var = pd.Series(dtype='float64')
    mfcc8_var = pd.Series(dtype='float64')
    mfcc9_var = pd.Series(dtype='float64')
    mfcc10_var = pd.Series(dtype='float64')
    mfcc11_var = pd.Series(dtype='float64')
    mfcc12_var = pd.Series(dtype='float64')
    mfcc13_var = pd.Series(dtype='float64')
    mfcc14_var = pd.Series(dtype='float64')
    mfcc15_var = pd.Series(dtype='float64')
    mfcc16_var = pd.Series(dtype='float64')
    mfcc17_var = pd.Series(dtype='float64')
    mfcc18_var = pd.Series(dtype='float64')
    mfcc19_var = pd.Series(dtype='float64')
    mfcc20_var = pd.Series(dtype='float64')

    mfcc1_delta_mean = pd.Series(dtype='float64')
    mfcc2_delta_mean = pd.Series(dtype='float64')
    mfcc3_delta_mean = pd.Series(dtype='float64')
    mfcc4_delta_mean = pd.Series(dtype='float64')
    mfcc5_delta_mean = pd.Series(dtype='float64')
    mfcc6_delta_mean = pd.Series(dtype='float64')
    mfcc7_delta_mean = pd.Series(dtype='float64')
    mfcc8_delta_mean = pd.Series(dtype='float64')
    mfcc9_delta_mean = pd.Series(dtype='float64')
    mfcc10_delta_mean = pd.Series(dtype='float64')
    mfcc11_delta_mean = pd.Series(dtype='float64')
    mfcc12_delta_mean = pd.Series(dtype='float64')
    mfcc13_delta_mean = pd.Series(dtype='float64')
    mfcc14_delta_mean = pd.Series(dtype='float64')
    mfcc15_delta_mean = pd.Series(dtype='float64')
    mfcc16_delta_mean = pd.Series(dtype='float64')
    mfcc17_delta_mean = pd.Series(dtype='float64')
    mfcc18_delta_mean = pd.Series(dtype='float64')
    mfcc19_delta_mean = pd.Series(dtype='float64')
    mfcc20_delta_mean = pd.Series(dtype='float64')
    
    mfcc1_delta_std = pd.Series(dtype='float64')
    mfcc2_delta_std = pd.Series(dtype='float64')
    mfcc3_delta_std = pd.Series(dtype='float64')
    mfcc4_delta_std = pd.Series(dtype='float64')
    mfcc5_delta_std = pd.Series(dtype='float64')
    mfcc6_delta_std = pd.Series(dtype='float64')
    mfcc7_delta_std = pd.Series(dtype='float64')
    mfcc8_delta_std = pd.Series(dtype='float64')
    mfcc9_delta_std = pd.Series(dtype='float64')
    mfcc10_delta_std = pd.Series(dtype='float64')
    mfcc11_delta_std = pd.Series(dtype='float64')
    mfcc12_delta_std = pd.Series(dtype='float64')
    mfcc13_delta_std = pd.Series(dtype='float64')
    mfcc14_delta_std = pd.Series(dtype='float64')
    mfcc15_delta_std = pd.Series(dtype='float64')
    mfcc16_delta_std = pd.Series(dtype='float64')
    mfcc17_delta_std = pd.Series(dtype='float64')
    mfcc18_delta_std = pd.Series(dtype='float64')
    mfcc19_delta_std = pd.Series(dtype='float64')
    mfcc20_delta_std = pd.Series(dtype='float64')

    mfcc1_delta_var = pd.Series(dtype='float64')
    mfcc2_delta_var = pd.Series(dtype='float64')
    mfcc3_delta_var = pd.Series(dtype='float64')
    mfcc4_delta_var = pd.Series(dtype='float64')
    mfcc5_delta_var = pd.Series(dtype='float64')
    mfcc6_delta_var = pd.Series(dtype='float64')
    mfcc7_delta_var = pd.Series(dtype='float64')
    mfcc8_delta_var = pd.Series(dtype='float64')
    mfcc9_delta_var = pd.Series(dtype='float64')
    mfcc10_delta_var = pd.Series(dtype='float64')
    mfcc11_delta_var = pd.Series(dtype='float64')
    mfcc12_delta_var = pd.Series(dtype='float64')
    mfcc13_delta_var = pd.Series(dtype='float64')
    mfcc14_delta_var = pd.Series(dtype='float64')
    mfcc15_delta_var = pd.Series(dtype='float64')
    mfcc16_delta_var = pd.Series(dtype='float64')
    mfcc17_delta_var = pd.Series(dtype='float64')
    mfcc18_delta_var = pd.Series(dtype='float64')
    mfcc19_delta_var = pd.Series(dtype='float64')
    mfcc20_delta_var = pd.Series(dtype='float64')

    rmse_mean = pd.Series(dtype='float64')
    rmse_std = pd.Series(dtype='float64')
    rmse_var = pd.Series(dtype='float64')
    cent_mean = pd.Series(dtype='float64')
    cent_std = pd.Series(dtype='float64')
    cent_var = pd.Series(dtype='float64')
    spec_bw_mean = pd.Series(dtype='float64')
    spec_bw_std = pd.Series(dtype='float64')
    spec_bw_var = pd.Series(dtype='float64')
    contrast_mean = pd.Series(dtype='float64')
    contrast_std = pd.Series(dtype='float64')
    contrast_var = pd.Series(dtype='float64')
    rolloff_mean = pd.Series(dtype='float64')
    rolloff_std = pd.Series(dtype='float64')
    rolloff_var = pd.Series(dtype='float64')
    poly_mean = pd.Series(dtype='float64')
    poly_std = pd.Series(dtype='float64')
    poly_var = pd.Series(dtype='float64')
    tonnetz_mean = pd.Series(dtype='float64')
    tonnetz_std = pd.Series(dtype='float64')
    tonnetz_var = pd.Series(dtype='float64')
    zcr_mean = pd.Series(dtype='float64')
    zcr_std = pd.Series(dtype='float64')
    zcr_var = pd.Series(dtype='float64')
    harm_mean = pd.Series(dtype='float64')
    harm_std = pd.Series(dtype='float64')
    harm_var = pd.Series(dtype='float64')
    perc_mean = pd.Series(dtype='float64')
    perc_std = pd.Series(dtype='float64')
    perc_var = pd.Series(dtype='float64')
    frame_mean = pd.Series(dtype='float64')
    frame_std = pd.Series(dtype='float64')
    frame_var = pd.Series(dtype='float64')
    
    
    # 找出路徑資料夾下的所有檔案 ,輸出成 list
    file_data = [f for f in listdir(path) if isfile (join(path, f))]
    
    # list內的每個元素(資料長相:'檔名')取出來
    for line in file_data:
        if ( line[-1:] == '\n' ):   # 從換行前面取黨檔名
            line = line[:-1]     # 不取逗號

        # 讀取音檔
        songname = path + line # 將 目錄路徑跟檔名 合併成 檔案路徑
        y, sr = librosa.load(songname) # 用 librosa讀取檔案
        S = np.abs(librosa.stft(y)) # 傅立葉轉換取振幅
        
        # 特徵提取
        tempo, beats = librosa.beat.beat_track(y=y, sr=sr)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        chroma_cq = librosa.feature.chroma_cqt(y=y, sr=sr)
        chroma_cens = librosa.feature.chroma_cens(y=y, sr=sr)
        melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
        rmse = librosa.feature.rms(y=y)
        cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        contrast = librosa.feature.spectral_contrast(S=S, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        poly_features = librosa.feature.poly_features(S=S, sr=sr)
        tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        harmonic = librosa.effects.harmonic(y)
        percussive = librosa.effects.percussive(y)
        
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        mfcc_delta = librosa.feature.delta(mfcc)
    
        onset_frames = librosa.onset.onset_detect(y=y, sr=sr)
        frames_to_time = librosa.frames_to_time(onset_frames[:20], sr=sr)
        
        # 將提取出各個特徵的值丟進前面建的 Series欄位變數
        songname_vector._set_value(id, line)  # song name
        tempo_vector._set_value(id, tempo)  # tempo
        total_beats._set_value(id, sum(beats))  # beats
        average_beats._set_value(id, np.average(beats))
        chroma_stft_mean._set_value(id, np.mean(chroma_stft))  # chroma stft
        chroma_stft_std._set_value(id, np.std(chroma_stft))
        chroma_stft_var._set_value(id, np.var(chroma_stft))
        chroma_cq_mean._set_value(id, np.mean(chroma_cq))  # chroma cq
        chroma_cq_std._set_value(id, np.std(chroma_cq))
        chroma_cq_var._set_value(id, np.var(chroma_cq))
        chroma_cens_mean._set_value(id, np.mean(chroma_cens))  # chroma cens
        chroma_cens_std._set_value(id, np.std(chroma_cens))
        chroma_cens_var._set_value(id, np.var(chroma_cens))
        mel_mean._set_value(id, np.mean(melspectrogram))  # melspectrogram
        mel_std._set_value(id, np.std(melspectrogram))
        mel_var._set_value(id, np.var(melspectrogram))
        
#         mfcc_mean._set_value(id, np.mean(mfcc))
#         mfcc_std._set_value(id, np.std(mfcc))
#         mfcc_var._set_value(id, np.var(mfcc))
#         mfcc_delta_mean._set_value(id, np.mean(mfcc_delta))  # mfcc delta
#         mfcc_delta_std._set_value(id, np.std(mfcc_delta))
#         mfcc_delta_var._set_value(id, np.var(mfcc_delta))

        mfcc1_mean._set_value(id, np.mean(mfcc[0]))
        mfcc2_mean._set_value(id, np.mean(mfcc[1]))
        mfcc3_mean._set_value(id, np.mean(mfcc[2]))
        mfcc4_mean._set_value(id, np.mean(mfcc[3]))
        mfcc5_mean._set_value(id, np.mean(mfcc[4]))
        mfcc6_mean._set_value(id, np.mean(mfcc[5]))
        mfcc7_mean._set_value(id, np.mean(mfcc[6]))
        mfcc8_mean._set_value(id, np.mean(mfcc[7]))
        mfcc9_mean._set_value(id, np.mean(mfcc[8]))
        mfcc10_mean._set_value(id, np.mean(mfcc[9]))
        mfcc11_mean._set_value(id, np.mean(mfcc[10]))
        mfcc12_mean._set_value(id, np.mean(mfcc[11]))
        mfcc13_mean._set_value(id, np.mean(mfcc[12]))
        mfcc14_mean._set_value(id, np.mean(mfcc[13]))
        mfcc15_mean._set_value(id, np.mean(mfcc[14]))
        mfcc16_mean._set_value(id, np.mean(mfcc[15]))
        mfcc17_mean._set_value(id, np.mean(mfcc[16]))
        mfcc18_mean._set_value(id, np.mean(mfcc[17]))
        mfcc19_mean._set_value(id, np.mean(mfcc[18]))
        mfcc20_mean._set_value(id, np.mean(mfcc[19]))
        
        mfcc1_std._set_value(id, np.std(mfcc[0]))
        mfcc2_std._set_value(id, np.std(mfcc[1]))
        mfcc3_std._set_value(id, np.std(mfcc[2]))
        mfcc4_std._set_value(id, np.std(mfcc[3]))
        mfcc5_std._set_value(id, np.std(mfcc[4]))
        mfcc6_std._set_value(id, np.std(mfcc[5]))
        mfcc7_std._set_value(id, np.std(mfcc[6]))
        mfcc8_std._set_value(id, np.std(mfcc[7]))
        mfcc9_std._set_value(id, np.std(mfcc[8]))
        mfcc10_std._set_value(id, np.std(mfcc[9]))
        mfcc11_std._set_value(id, np.std(mfcc[10]))
        mfcc12_std._set_value(id, np.std(mfcc[11]))
        mfcc13_std._set_value(id, np.std(mfcc[12]))
        mfcc14_std._set_value(id, np.std(mfcc[13]))
        mfcc15_std._set_value(id, np.std(mfcc[14]))
        mfcc16_std._set_value(id, np.std(mfcc[15]))
        mfcc17_std._set_value(id, np.std(mfcc[16]))
        mfcc18_std._set_value(id, np.std(mfcc[17]))
        mfcc19_std._set_value(id, np.std(mfcc[18]))
        mfcc20_std._set_value(id, np.std(mfcc[19]))
        
        mfcc1_var._set_value(id, np.var(mfcc[0]))
        mfcc2_var._set_value(id, np.var(mfcc[1]))
        mfcc3_var._set_value(id, np.var(mfcc[2]))
        mfcc4_var._set_value(id, np.var(mfcc[3]))
        mfcc5_var._set_value(id, np.var(mfcc[4]))
        mfcc6_var._set_value(id, np.var(mfcc[5]))
        mfcc7_var._set_value(id, np.var(mfcc[6]))
        mfcc8_var._set_value(id, np.var(mfcc[7]))
        mfcc9_var._set_value(id, np.var(mfcc[8]))
        mfcc10_var._set_value(id, np.var(mfcc[9]))
        mfcc11_var._set_value(id, np.var(mfcc[10]))
        mfcc12_var._set_value(id, np.var(mfcc[11]))
        mfcc13_var._set_value(id, np.var(mfcc[12]))
        mfcc14_var._set_value(id, np.var(mfcc[13]))
        mfcc15_var._set_value(id, np.var(mfcc[14]))
        mfcc16_var._set_value(id, np.var(mfcc[15]))
        mfcc17_var._set_value(id, np.var(mfcc[16]))
        mfcc18_var._set_value(id, np.var(mfcc[17]))
        mfcc19_var._set_value(id, np.var(mfcc[18]))
        mfcc20_var._set_value(id, np.var(mfcc[19]))
        
        mfcc1_delta_mean._set_value(id, np.mean(mfcc_delta[0]))
        mfcc2_delta_mean._set_value(id, np.mean(mfcc_delta[1]))
        mfcc3_delta_mean._set_value(id, np.mean(mfcc_delta[2]))
        mfcc4_delta_mean._set_value(id, np.mean(mfcc_delta[3]))
        mfcc5_delta_mean._set_value(id, np.mean(mfcc_delta[4]))
        mfcc6_delta_mean._set_value(id, np.mean(mfcc_delta[5]))
        mfcc7_delta_mean._set_value(id, np.mean(mfcc_delta[6]))
        mfcc8_delta_mean._set_value(id, np.mean(mfcc_delta[7]))
        mfcc9_delta_mean._set_value(id, np.mean(mfcc_delta[8]))
        mfcc10_delta_mean._set_value(id, np.mean(mfcc_delta[9]))
        mfcc11_delta_mean._set_value(id, np.mean(mfcc_delta[10]))
        mfcc12_delta_mean._set_value(id, np.mean(mfcc_delta[11]))
        mfcc13_delta_mean._set_value(id, np.mean(mfcc_delta[12]))
        mfcc14_delta_mean._set_value(id, np.mean(mfcc_delta[13]))
        mfcc15_delta_mean._set_value(id, np.mean(mfcc_delta[14]))
        mfcc16_delta_mean._set_value(id, np.mean(mfcc_delta[15]))
        mfcc17_delta_mean._set_value(id, np.mean(mfcc_delta[16]))
        mfcc18_delta_mean._set_value(id, np.mean(mfcc_delta[17]))
        mfcc19_delta_mean._set_value(id, np.mean(mfcc_delta[18]))
        mfcc20_delta_mean._set_value(id, np.mean(mfcc_delta[19]))
        
        mfcc1_delta_std._set_value(id, np.std(mfcc_delta[0]))
        mfcc2_delta_std._set_value(id, np.std(mfcc_delta[1]))
        mfcc3_delta_std._set_value(id, np.std(mfcc_delta[2]))
        mfcc4_delta_std._set_value(id, np.std(mfcc_delta[3]))
        mfcc5_delta_std._set_value(id, np.std(mfcc_delta[4]))
        mfcc6_delta_std._set_value(id, np.std(mfcc_delta[5]))
        mfcc7_delta_std._set_value(id, np.std(mfcc_delta[6]))
        mfcc8_delta_std._set_value(id, np.std(mfcc_delta[7]))
        mfcc9_delta_std._set_value(id, np.std(mfcc_delta[8]))
        mfcc10_delta_std._set_value(id, np.std(mfcc_delta[9]))
        mfcc11_delta_std._set_value(id, np.std(mfcc_delta[10]))
        mfcc12_delta_std._set_value(id, np.std(mfcc_delta[11]))
        mfcc13_delta_std._set_value(id, np.std(mfcc_delta[12]))
        mfcc14_delta_std._set_value(id, np.std(mfcc_delta[13]))
        mfcc15_delta_std._set_value(id, np.std(mfcc_delta[14]))
        mfcc16_delta_std._set_value(id, np.std(mfcc_delta[15]))
        mfcc17_delta_std._set_value(id, np.std(mfcc_delta[16]))
        mfcc18_delta_std._set_value(id, np.std(mfcc_delta[17]))
        mfcc19_delta_std._set_value(id, np.std(mfcc_delta[18]))
        mfcc20_delta_std._set_value(id, np.std(mfcc_delta[19]))
        
        mfcc1_delta_var._set_value(id, np.var(mfcc_delta[0]))
        mfcc2_delta_var._set_value(id, np.var(mfcc_delta[1]))
        mfcc3_delta_var._set_value(id, np.var(mfcc_delta[2]))
        mfcc4_delta_var._set_value(id, np.var(mfcc_delta[3]))
        mfcc5_delta_var._set_value(id, np.var(mfcc_delta[4]))
        mfcc6_delta_var._set_value(id, np.var(mfcc_delta[5]))
        mfcc7_delta_var._set_value(id, np.var(mfcc_delta[6]))
        mfcc8_delta_var._set_value(id, np.var(mfcc_delta[7]))
        mfcc9_delta_var._set_value(id, np.var(mfcc_delta[8]))
        mfcc10_delta_var._set_value(id, np.var(mfcc_delta[9]))
        mfcc11_delta_var._set_value(id, np.var(mfcc_delta[10]))
        mfcc12_delta_var._set_value(id, np.var(mfcc_delta[11]))
        mfcc13_delta_var._set_value(id, np.var(mfcc_delta[12]))
        mfcc14_delta_var._set_value(id, np.var(mfcc_delta[13]))
        mfcc15_delta_var._set_value(id, np.var(mfcc_delta[14]))
        mfcc16_delta_var._set_value(id, np.var(mfcc_delta[15]))
        mfcc17_delta_var._set_value(id, np.var(mfcc_delta[16]))
        mfcc18_delta_var._set_value(id, np.var(mfcc_delta[17]))
        mfcc19_delta_var._set_value(id, np.var(mfcc_delta[18]))
        mfcc20_delta_var._set_value(id, np.var(mfcc_delta[19]))
        
        rmse_mean._set_value(id, np.mean(rmse))  # rmse
        rmse_std._set_value(id, np.std(rmse))
        rmse_var._set_value(id, np.var(rmse))
        cent_mean._set_value(id, np.mean(cent))  # cent
        cent_std._set_value(id, np.std(cent))
        cent_var._set_value(id, np.var(cent))
        spec_bw_mean._set_value(id, np.mean(spec_bw))  # spectral bandwidth
        spec_bw_std._set_value(id, np.std(spec_bw))
        spec_bw_var._set_value(id, np.var(spec_bw))
        contrast_mean._set_value(id, np.mean(contrast))  # contrast
        contrast_std._set_value(id, np.std(contrast))
        contrast_var._set_value(id, np.var(contrast))
        rolloff_mean._set_value(id, np.mean(rolloff))  # rolloff
        rolloff_std._set_value(id, np.std(rolloff))
        rolloff_var._set_value(id, np.var(rolloff))
        poly_mean._set_value(id, np.mean(poly_features))  # poly features
        poly_std._set_value(id, np.std(poly_features))
        poly_var._set_value(id, np.var(poly_features))
        tonnetz_mean._set_value(id, np.mean(tonnetz))  # tonnetz
        tonnetz_std._set_value(id, np.std(tonnetz))
        tonnetz_var._set_value(id, np.var(tonnetz))
        zcr_mean._set_value(id, np.mean(zcr))  # zero crossing rate
        zcr_std._set_value(id, np.std(zcr))
        zcr_var._set_value(id, np.var(zcr))
        harm_mean._set_value(id, np.mean(harmonic))  # harmonic
        harm_std._set_value(id, np.std(harmonic))
        harm_var._set_value(id, np.var(harmonic))
        perc_mean._set_value(id, np.mean(percussive))  # percussive
        perc_std._set_value(id, np.std(percussive))
        perc_var._set_value(id, np.var(percussive))
        frame_mean._set_value(id, np.mean(frames_to_time))  # frames
        frame_std._set_value(id, np.std(frames_to_time))
        frame_var._set_value(id, np.var(frames_to_time))
        
        
        print(songname)
        id = id+1   #完成換下一首歌
    
    # 將各個 Series 加入前面建的 feature_set dataframe裡
    feature_set['song_name'] = songname_vector  # song name
    feature_set['tempo'] = tempo_vector  # tempo 
    feature_set['total_beats'] = total_beats  # beats
    feature_set['average_beats'] = average_beats
    feature_set['chroma_stft_mean'] = chroma_stft_mean  # chroma stft
    feature_set['chroma_stft_std'] = chroma_stft_std
    feature_set['chroma_stft_var'] = chroma_stft_var
    feature_set['chroma_cq_mean'] = chroma_cq_mean  # chroma cq
    feature_set['chroma_cq_std'] = chroma_cq_std
    feature_set['chroma_cq_var'] = chroma_cq_var
    feature_set['chroma_cens_mean'] = chroma_cens_mean  # chroma cens
    feature_set['chroma_cens_std'] = chroma_cens_std
    feature_set['chroma_cens_var'] = chroma_cens_var
    feature_set['melspectrogram_mean'] = mel_mean  # melspectrogram
    feature_set['melspectrogram_std'] = mel_std
    feature_set['melspectrogram_var'] = mel_var
#     feature_set['mfcc_mean'] = mfcc_mean  # mfcc
#     feature_set['mfcc_std'] = mfcc_std
#     feature_set['mfcc_var'] = mfcc_var
#     feature_set['mfcc_delta_mean'] = mfcc_delta_mean  # mfcc delta
#     feature_set['mfcc_delta_std'] = mfcc_delta_std
#     feature_set['mfcc_delta_var'] = mfcc_delta_var

    feature_set['mfcc1_mean'] = mfcc1_mean
    feature_set['mfcc2_mean'] = mfcc2_mean
    feature_set['mfcc3_mean'] = mfcc3_mean
    feature_set['mfcc4_mean'] = mfcc4_mean
    feature_set['mfcc5_mean'] = mfcc5_mean
    feature_set['mfcc6_mean'] = mfcc6_mean
    feature_set['mfcc7_mean'] = mfcc7_mean
    feature_set['mfcc8_mean'] = mfcc8_mean
    feature_set['mfcc9_mean'] = mfcc9_mean
    feature_set['mfcc10_mean'] = mfcc10_mean
    feature_set['mfcc11_mean'] = mfcc11_mean
    feature_set['mfcc12_mean'] = mfcc12_mean
    feature_set['mfcc13_mean'] = mfcc13_mean
    feature_set['mfcc14_mean'] = mfcc14_mean
    feature_set['mfcc15_mean'] = mfcc15_mean
    feature_set['mfcc16_mean'] = mfcc16_mean
    feature_set['mfcc17_mean'] = mfcc17_mean
    feature_set['mfcc18_mean'] = mfcc18_mean
    feature_set['mfcc19_mean'] = mfcc19_mean
    feature_set['mfcc20_mean'] = mfcc20_mean
    
    feature_set['mfcc1_std'] = mfcc1_std
    feature_set['mfcc2_std'] = mfcc2_std
    feature_set['mfcc3_std'] = mfcc3_std
    feature_set['mfcc4_std'] = mfcc4_std
    feature_set['mfcc5_std'] = mfcc5_std
    feature_set['mfcc6_std'] = mfcc6_std
    feature_set['mfcc7_std'] = mfcc7_std
    feature_set['mfcc8_std'] = mfcc8_std
    feature_set['mfcc9_std'] = mfcc9_std
    feature_set['mfcc10_std'] = mfcc10_std
    feature_set['mfcc11_std'] = mfcc11_std
    feature_set['mfcc12_std'] = mfcc12_std
    feature_set['mfcc13_std'] = mfcc13_std
    feature_set['mfcc14_std'] = mfcc14_std
    feature_set['mfcc15_std'] = mfcc15_std
    feature_set['mfcc16_std'] = mfcc16_std
    feature_set['mfcc17_std'] = mfcc17_std
    feature_set['mfcc18_std'] = mfcc18_std
    feature_set['mfcc19_std'] = mfcc19_std
    feature_set['mfcc20_std'] = mfcc20_std
    
    feature_set['mfcc1_var'] = mfcc1_var
    feature_set['mfcc2_var'] = mfcc2_var
    feature_set['mfcc3_var'] = mfcc3_var
    feature_set['mfcc4_var'] = mfcc4_var
    feature_set['mfcc5_var'] = mfcc5_var
    feature_set['mfcc6_var'] = mfcc6_var
    feature_set['mfcc7_var'] = mfcc7_var
    feature_set['mfcc8_var'] = mfcc8_var
    feature_set['mfcc9_var'] = mfcc9_var
    feature_set['mfcc10_var'] = mfcc10_var
    feature_set['mfcc11_var'] = mfcc11_var
    feature_set['mfcc12_var'] = mfcc12_var
    feature_set['mfcc13_var'] = mfcc13_var
    feature_set['mfcc14_var'] = mfcc14_var
    feature_set['mfcc15_var'] = mfcc15_var
    feature_set['mfcc16_var'] = mfcc16_var
    feature_set['mfcc17_var'] = mfcc17_var
    feature_set['mfcc18_var'] = mfcc18_var
    feature_set['mfcc19_var'] = mfcc19_var
    feature_set['mfcc20_var'] = mfcc20_var
    
    feature_set['mfcc1_delta_mean'] = mfcc1_delta_mean
    feature_set['mfcc2_delta_mean'] = mfcc2_delta_mean
    feature_set['mfcc3_delta_mean'] = mfcc3_delta_mean
    feature_set['mfcc4_delta_mean'] = mfcc4_delta_mean
    feature_set['mfcc5_delta_mean'] = mfcc5_delta_mean
    feature_set['mfcc6_delta_mean'] = mfcc6_delta_mean
    feature_set['mfcc7_delta_mean'] = mfcc7_delta_mean
    feature_set['mfcc8_delta_mean'] = mfcc8_delta_mean
    feature_set['mfcc9_delta_mean'] = mfcc9_delta_mean
    feature_set['mfcc10_delta_mean'] = mfcc10_delta_mean
    feature_set['mfcc11_delta_mean'] = mfcc11_delta_mean
    feature_set['mfcc12_delta_mean'] = mfcc12_delta_mean
    feature_set['mfcc13_delta_mean'] = mfcc13_delta_mean
    feature_set['mfcc14_delta_mean'] = mfcc14_delta_mean
    feature_set['mfcc15_delta_mean'] = mfcc15_delta_mean
    feature_set['mfcc16_delta_mean'] = mfcc16_delta_mean
    feature_set['mfcc17_delta_mean'] = mfcc17_delta_mean
    feature_set['mfcc18_delta_mean'] = mfcc18_delta_mean
    feature_set['mfcc19_delta_mean'] = mfcc19_delta_mean
    feature_set['mfcc20_delta_mean'] = mfcc20_delta_mean
    
    feature_set['mfcc1_delta_std'] = mfcc1_delta_std
    feature_set['mfcc2_delta_std'] = mfcc2_delta_std
    feature_set['mfcc3_delta_std'] = mfcc3_delta_std
    feature_set['mfcc4_delta_std'] = mfcc4_delta_std
    feature_set['mfcc5_delta_std'] = mfcc5_delta_std
    feature_set['mfcc6_delta_std'] = mfcc6_delta_std
    feature_set['mfcc7_delta_std'] = mfcc7_delta_std
    feature_set['mfcc8_delta_std'] = mfcc8_delta_std
    feature_set['mfcc9_delta_std'] = mfcc9_delta_std
    feature_set['mfcc10_delta_std'] = mfcc10_delta_std
    feature_set['mfcc11_delta_std'] = mfcc11_delta_std
    feature_set['mfcc12_delta_std'] = mfcc12_delta_std
    feature_set['mfcc13_delta_std'] = mfcc13_delta_std
    feature_set['mfcc14_delta_std'] = mfcc14_delta_std
    feature_set['mfcc15_delta_std'] = mfcc15_delta_std
    feature_set['mfcc16_delta_std'] = mfcc16_delta_std
    feature_set['mfcc17_delta_std'] = mfcc17_delta_std
    feature_set['mfcc18_delta_std'] = mfcc18_delta_std
    feature_set['mfcc19_delta_std'] = mfcc19_delta_std
    feature_set['mfcc20_delta_std'] = mfcc20_delta_std
    
    feature_set['mfcc1_delta_var'] = mfcc1_delta_var
    feature_set['mfcc2_delta_var'] = mfcc2_delta_var
    feature_set['mfcc3_delta_var'] = mfcc3_delta_var
    feature_set['mfcc4_delta_var'] = mfcc4_delta_var
    feature_set['mfcc5_delta_var'] = mfcc5_delta_var
    feature_set['mfcc6_delta_var'] = mfcc6_delta_var
    feature_set['mfcc7_delta_var'] = mfcc7_delta_var
    feature_set['mfcc8_delta_var'] = mfcc8_delta_var
    feature_set['mfcc9_delta_var'] = mfcc9_delta_var
    feature_set['mfcc10_delta_var'] = mfcc10_delta_var
    feature_set['mfcc11_delta_var'] = mfcc11_delta_var
    feature_set['mfcc12_delta_var'] = mfcc12_delta_var
    feature_set['mfcc13_delta_var'] = mfcc13_delta_var
    feature_set['mfcc14_delta_var'] = mfcc14_delta_var
    feature_set['mfcc15_delta_var'] = mfcc15_delta_var
    feature_set['mfcc16_delta_var'] = mfcc16_delta_var
    feature_set['mfcc17_delta_var'] = mfcc17_delta_var
    feature_set['mfcc18_delta_var'] = mfcc18_delta_var
    feature_set['mfcc19_delta_var'] = mfcc19_delta_var
    feature_set['mfcc20_delta_var'] = mfcc20_delta_var

    feature_set['rmse_mean'] = rmse_mean  # rmse
    feature_set['rmse_std'] = rmse_std
    feature_set['rmse_var'] = rmse_var
    feature_set['cent_mean'] = cent_mean  # cent
    feature_set['cent_std'] = cent_std
    feature_set['cent_var'] = cent_var
    feature_set['spec_bw_mean'] = spec_bw_mean  # spectral bandwidth
    feature_set['spec_bw_std'] = spec_bw_std
    feature_set['spec_bw_var'] = spec_bw_var
    feature_set['contrast_mean'] = contrast_mean  # contrast
    feature_set['contrast_std'] = contrast_std
    feature_set['contrast_var'] = contrast_var
    feature_set['rolloff_mean'] = rolloff_mean  # rolloff
    feature_set['rolloff_std'] = rolloff_std
    feature_set['rolloff_var'] = rolloff_var
    feature_set['poly_mean'] = poly_mean  # poly features
    feature_set['poly_std'] = poly_std
    feature_set['poly_var'] = poly_var
    feature_set['tonnetz_mean'] = tonnetz_mean  # tonnetz
    feature_set['tonnetz_std'] = tonnetz_std
    feature_set['tonnetz_var'] = tonnetz_var
    feature_set['zcr_mean'] = zcr_mean  # zero crossing rate
    feature_set['zcr_std'] = zcr_std
    feature_set['zcr_var'] = zcr_var
    feature_set['harm_mean'] = harm_mean  # harmonic
    feature_set['harm_std'] = harm_std
    feature_set['harm_var'] = harm_var
    feature_set['perc_mean'] = perc_mean  # percussive
    feature_set['perc_std'] = perc_std
    feature_set['perc_var'] = perc_var
    feature_set['frame_mean'] = frame_mean  # frames
    feature_set['frame_std'] = frame_std
    feature_set['frame_var'] = frame_var

    # 匯出成json及csv檔
    # feature_set.to_json('Emotion_features.json')
    feature_set.to_csv('%s.csv' %(dir))

# %%
# 這個cell不要理我，原本要一次轉全部的csv出來，後來想說怕太久還是一個一個轉
# for root,dirs,files in os.walk("./musicfile/test"):
#     for dir in dirs:
#         #獲取目錄的名稱
# #         print(dir)
#         #獲取目錄的路徑
#         path = os.path.join(root,dir).replace( '\\' , '/' )
#         path = path + '/'
#         print(path)
#         extract_feature(path)

# %% [markdown]
# ## 呼叫函式

# %%
start = time.perf_counter()  # 開始時間

dir = 'disco3s' # 給檔名

extract_feature('./musicfile/3s/disco/')  # 給音檔目錄並呼叫函式

print("This time is being calculated")

end = time.perf_counter()  #結束時間

print(end - start) # 計算時長
# Out:
# ./musicfile/3s/disco/disco1-1-0.wav
# ./musicfile/3s/disco/disco1-1-1.wav
# ./musicfile/3s/disco/disco1-1-2.wav
# ./musicfile/3s/disco/disco1-1-3.wav
# ./musicfile/3s/disco/disco1-1-4.wav
# ./musicfile/3s/disco/disco1-1-5.wav
# ./musicfile/3s/disco/disco1-1-6.wav
# ./musicfile/3s/disco/disco1-1-7.wav
# ./musicfile/3s/disco/disco1-1-8.wav
# ./musicfile/3s/disco/disco1-1-9.wav
# ./musicfile/3s/disco/disco1-2-0.wav
# ./musicfile/3s/disco/disco1-2-1.wav
# ./musicfile/3s/disco/disco1-2-2.wav
# ./musicfile/3s/disco/disco1-2-3.wav
# ./musicfile/3s/disco/disco1-2-4.wav
# ./musicfile/3s/disco/disco1-2-5.wav
# ./musicfile/3s/disco/disco1-2-6.wav
# ./musicfile/3s/disco/disco1-2-7.wav
# ./musicfile/3s/disco/disco1-2-8.wav
# ./musicfile/3s/disco/disco1-2-9.wav
# ./musicfile/3s/disco/disco1-3-0.wav
# ./musicfile/3s/disco/disco1-3-1.wav
# ./musicfile/3s/disco/disco1-3-2.wav
# ./musicfile/3s/disco/disco1-3-3.wav
# ./musicfile/3s/disco/disco1-3-4.wav
# ./musicfile/3s/disco/disco1-3-5.wav
# ./musicfile/3s/disco/disco1-3-6.wav
# ./musicfile/3s/disco/disco1-3-7.wav
# ./musicfile/3s/disco/disco1-3-8.wav
# ./musicfile/3s/disco/disco1-3-9.wav
# ./musicfile/3s/disco/disco1-4-0.wav
# ./musicfile/3s/disco/disco1-4-1.wav
# ./musicfile/3s/disco/disco1-4-2.wav
# ./musicfile/3s/disco/disco1-4-3.wav
# ./musicfile/3s/disco/disco1-4-4.wav
# ./musicfile/3s/disco/disco1-4-5.wav
# ./musicfile/3s/disco/disco1-4-6.wav
# ./musicfile/3s/disco/disco1-4-7.wav
# ./musicfile/3s/disco/disco1-4-8.wav
# ./musicfile/3s/disco/disco1-4-9.wav
# ./musicfile/3s/disco/disco1-5-0.wav
# ./musicfile/3s/disco/disco1-5-1.wav
# ./musicfile/3s/disco/disco1-5-2.wav
# ./musicfile/3s/disco/disco1-5-3.wav
# ./musicfile/3s/disco/disco1-5-4.wav
# ./musicfile/3s/disco/disco1-5-5.wav
# ./musicfile/3s/disco/disco1-5-6.wav
# ./musicfile/3s/disco/disco1-5-7.wav
# ./musicfile/3s/disco/disco1-5-8.wav
# ./musicfile/3s/disco/disco1-5-9.wav
# ./musicfile/3s/disco/disco1-6-0.wav
# ./musicfile/3s/disco/disco1-6-1.wav
# ./musicfile/3s/disco/disco1-6-2.wav
# ./musicfile/3s/disco/disco1-6-3.wav
# ./musicfile/3s/disco/disco1-6-4.wav
# ./musicfile/3s/disco/disco1-6-5.wav
# ./musicfile/3s/disco/disco1-6-6.wav
# ./musicfile/3s/disco/disco1-6-7.wav
# ./musicfile/3s/disco/disco1-6-8.wav
# ./musicfile/3s/disco/disco1-6-9.wav
# ./musicfile/3s/disco/disco10-1-0.wav
# ./musicfile/3s/disco/disco10-1-1.wav
# ./musicfile/3s/disco/disco10-1-2.wav
# ./musicfile/3s/disco/disco10-1-3.wav
# ./musicfile/3s/disco/disco10-1-4.wav
# ./musicfile/3s/disco/disco10-1-5.wav
# ./musicfile/3s/disco/disco10-1-6.wav
# ./musicfile/3s/disco/disco10-1-7.wav
# ./musicfile/3s/disco/disco10-1-8.wav
# ./musicfile/3s/disco/disco10-1-9.wav
# ./musicfile/3s/disco/disco10-10-0.wav
# ./musicfile/3s/disco/disco10-10-1.wav
# ./musicfile/3s/disco/disco10-10-2.wav
# ./musicfile/3s/disco/disco10-10-3.wav
# ./musicfile/3s/disco/disco10-10-4.wav
# ./musicfile/3s/disco/disco10-10-5.wav
# ./musicfile/3s/disco/disco10-10-6.wav
# ./musicfile/3s/disco/disco10-10-7.wav
# ./musicfile/3s/disco/disco10-10-8.wav
# ./musicfile/3s/disco/disco10-10-9.wav
# ./musicfile/3s/disco/disco10-2-0.wav
# ./musicfile/3s/disco/disco10-2-1.wav
# ./musicfile/3s/disco/disco10-2-2.wav
# ./musicfile/3s/disco/disco10-2-3.wav
# ./musicfile/3s/disco/disco10-2-4.wav
# ./musicfile/3s/disco/disco10-2-5.wav
# ./musicfile/3s/disco/disco10-2-6.wav
# ./musicfile/3s/disco/disco10-2-7.wav
# ./musicfile/3s/disco/disco10-2-8.wav
# ./musicfile/3s/disco/disco10-2-9.wav
# ./musicfile/3s/disco/disco10-3-0.wav
# ./musicfile/3s/disco/disco10-3-1.wav
# ./musicfile/3s/disco/disco10-3-2.wav
# ./musicfile/3s/disco/disco10-3-3.wav
# ./musicfile/3s/disco/disco10-3-4.wav
# ./musicfile/3s/disco/disco10-3-5.wav
# ./musicfile/3s/disco/disco10-3-6.wav
# ./musicfile/3s/disco/disco10-3-7.wav
# ./musicfile/3s/disco/disco10-3-8.wav
# ./musicfile/3s/disco/disco10-3-9.wav
# ./musicfile/3s/disco/disco10-4-0.wav
# ./musicfile/3s/disco/disco10-4-1.wav
# ./musicfile/3s/disco/disco10-4-2.wav
# ./musicfile/3s/disco/disco10-4-3.wav
# ./musicfile/3s/disco/disco10-4-4.wav
# ./musicfile/3s/disco/disco10-4-5.wav
# ./musicfile/3s/disco/disco10-4-6.wav
# ./musicfile/3s/disco/disco10-4-7.wav
# ./musicfile/3s/disco/disco10-4-8.wav
# ./musicfile/3s/disco/disco10-4-9.wav
# ./musicfile/3s/disco/disco10-5-0.wav
# ./musicfile/3s/disco/disco10-5-1.wav
# ./musicfile/3s/disco/disco10-5-2.wav
# ./musicfile/3s/disco/disco10-5-3.wav
# ./musicfile/3s/disco/disco10-5-4.wav
# ./musicfile/3s/disco/disco10-5-5.wav
# ./musicfile/3s/disco/disco10-5-6.wav
# ./musicfile/3s/disco/disco10-5-7.wav
# ./musicfile/3s/disco/disco10-5-8.wav
# ./musicfile/3s/disco/disco10-5-9.wav
# ./musicfile/3s/disco/disco10-6-0.wav
# ./musicfile/3s/disco/disco10-6-1.wav
# ./musicfile/3s/disco/disco10-6-2.wav
# ./musicfile/3s/disco/disco10-6-3.wav
# ./musicfile/3s/disco/disco10-6-4.wav
# ./musicfile/3s/disco/disco10-6-5.wav
# ./musicfile/3s/disco/disco10-6-6.wav
# ./musicfile/3s/disco/disco10-6-7.wav
# ./musicfile/3s/disco/disco10-6-8.wav
# ./musicfile/3s/disco/disco10-6-9.wav
# ./musicfile/3s/disco/disco10-7-0.wav
# ./musicfile/3s/disco/disco10-7-1.wav
# ./musicfile/3s/disco/disco10-7-2.wav
# ./musicfile/3s/disco/disco10-7-3.wav
# ./musicfile/3s/disco/disco10-7-4.wav
# ./musicfile/3s/disco/disco10-7-5.wav
# ./musicfile/3s/disco/disco10-7-6.wav
# ./musicfile/3s/disco/disco10-7-7.wav
# ./musicfile/3s/disco/disco10-7-8.wav
# ./musicfile/3s/disco/disco10-7-9.wav
# ./musicfile/3s/disco/disco10-8-0.wav
# ./musicfile/3s/disco/disco10-8-1.wav
# ./musicfile/3s/disco/disco10-8-2.wav
# ./musicfile/3s/disco/disco10-8-3.wav
# ./musicfile/3s/disco/disco10-8-4.wav
# ./musicfile/3s/disco/disco10-8-5.wav
# ./musicfile/3s/disco/disco10-8-6.wav
# ./musicfile/3s/disco/disco10-8-7.wav
# ./musicfile/3s/disco/disco10-8-8.wav
# ./musicfile/3s/disco/disco10-8-9.wav
# ./musicfile/3s/disco/disco10-9-0.wav
# ./musicfile/3s/disco/disco10-9-1.wav
# ./musicfile/3s/disco/disco10-9-2.wav
# ./musicfile/3s/disco/disco10-9-3.wav
# ./musicfile/3s/disco/disco10-9-4.wav
# ./musicfile/3s/disco/disco10-9-5.wav
# ./musicfile/3s/disco/disco10-9-6.wav
# ./musicfile/3s/disco/disco10-9-7.wav
# ./musicfile/3s/disco/disco10-9-8.wav
# ./musicfile/3s/disco/disco10-9-9.wav
# ./musicfile/3s/disco/disco11-1-0.wav
# ./musicfile/3s/disco/disco11-1-1.wav
# ./musicfile/3s/disco/disco11-1-2.wav
# ./musicfile/3s/disco/disco11-1-3.wav
# ./musicfile/3s/disco/disco11-1-4.wav
# ./musicfile/3s/disco/disco11-1-5.wav
# ./musicfile/3s/disco/disco11-1-6.wav
# ./musicfile/3s/disco/disco11-1-7.wav
# ./musicfile/3s/disco/disco11-1-8.wav
# ./musicfile/3s/disco/disco11-1-9.wav
# ./musicfile/3s/disco/disco11-2-0.wav
# ./musicfile/3s/disco/disco11-2-1.wav
# ./musicfile/3s/disco/disco11-2-2.wav
# ./musicfile/3s/disco/disco11-2-3.wav
# ./musicfile/3s/disco/disco11-2-4.wav
# ./musicfile/3s/disco/disco11-2-5.wav
# ./musicfile/3s/disco/disco11-2-6.wav
# ./musicfile/3s/disco/disco11-2-7.wav
# ./musicfile/3s/disco/disco11-2-8.wav
# ./musicfile/3s/disco/disco11-2-9.wav
# ./musicfile/3s/disco/disco11-3-0.wav
# ./musicfile/3s/disco/disco11-3-1.wav
# ./musicfile/3s/disco/disco11-3-2.wav
# ./musicfile/3s/disco/disco11-3-3.wav
# ./musicfile/3s/disco/disco11-3-4.wav
# ./musicfile/3s/disco/disco11-3-5.wav
# ./musicfile/3s/disco/disco11-3-6.wav
# ./musicfile/3s/disco/disco11-3-7.wav
# ./musicfile/3s/disco/disco11-3-8.wav
# ./musicfile/3s/disco/disco11-3-9.wav
# ./musicfile/3s/disco/disco11-4-0.wav
# ./musicfile/3s/disco/disco11-4-1.wav
# ./musicfile/3s/disco/disco11-4-2.wav
# ./musicfile/3s/disco/disco11-4-3.wav
# ./musicfile/3s/disco/disco11-4-4.wav
# ./musicfile/3s/disco/disco11-4-5.wav
# ./musicfile/3s/disco/disco11-4-6.wav
# ./musicfile/3s/disco/disco11-4-7.wav
# ./musicfile/3s/disco/disco11-4-8.wav
# ./musicfile/3s/disco/disco11-4-9.wav
# ./musicfile/3s/disco/disco11-5-0.wav
# ./musicfile/3s/disco/disco11-5-1.wav
# ./musicfile/3s/disco/disco11-5-2.wav
# ./musicfile/3s/disco/disco11-5-3.wav
# ./musicfile/3s/disco/disco11-5-4.wav
# ./musicfile/3s/disco/disco11-5-5.wav
# ./musicfile/3s/disco/disco11-5-6.wav
# ./musicfile/3s/disco/disco11-5-7.wav
# ./musicfile/3s/disco/disco11-5-8.wav
# ./musicfile/3s/disco/disco11-5-9.wav
# ./musicfile/3s/disco/disco12-1-0.wav
# ./musicfile/3s/disco/disco12-1-1.wav
# ./musicfile/3s/disco/disco12-1-2.wav
# ./musicfile/3s/disco/disco12-1-3.wav
# ./musicfile/3s/disco/disco12-1-4.wav
# ./musicfile/3s/disco/disco12-1-5.wav
# ./musicfile/3s/disco/disco12-1-6.wav
# ./musicfile/3s/disco/disco12-1-7.wav
# ./musicfile/3s/disco/disco12-1-8.wav
# ./musicfile/3s/disco/disco12-1-9.wav
# ./musicfile/3s/disco/disco12-2-0.wav
# ./musicfile/3s/disco/disco12-2-1.wav
# ./musicfile/3s/disco/disco12-2-2.wav
# ./musicfile/3s/disco/disco12-2-3.wav
# ./musicfile/3s/disco/disco12-2-4.wav
# ./musicfile/3s/disco/disco12-2-5.wav
# ./musicfile/3s/disco/disco12-2-6.wav
# ./musicfile/3s/disco/disco12-2-7.wav
# ./musicfile/3s/disco/disco12-2-8.wav
# ./musicfile/3s/disco/disco12-2-9.wav
# ./musicfile/3s/disco/disco12-3-0.wav
# ./musicfile/3s/disco/disco12-3-1.wav
# ./musicfile/3s/disco/disco12-3-2.wav
# ./musicfile/3s/disco/disco12-3-3.wav
# ./musicfile/3s/disco/disco12-3-4.wav
# ./musicfile/3s/disco/disco12-3-5.wav
# ./musicfile/3s/disco/disco12-3-6.wav
# ./musicfile/3s/disco/disco12-3-7.wav
# ./musicfile/3s/disco/disco12-3-8.wav
# ./musicfile/3s/disco/disco12-3-9.wav
# ./musicfile/3s/disco/disco12-4-0.wav
# ./musicfile/3s/disco/disco12-4-1.wav
# ./musicfile/3s/disco/disco12-4-2.wav
# ./musicfile/3s/disco/disco12-4-3.wav
# ./musicfile/3s/disco/disco12-4-4.wav
# ./musicfile/3s/disco/disco12-4-5.wav
# ./musicfile/3s/disco/disco12-4-6.wav
# ./musicfile/3s/disco/disco12-4-7.wav
# ./musicfile/3s/disco/disco12-4-8.wav
# ./musicfile/3s/disco/disco12-4-9.wav
# ./musicfile/3s/disco/disco12-5-0.wav
# ./musicfile/3s/disco/disco12-5-1.wav
# ./musicfile/3s/disco/disco12-5-2.wav
# ./musicfile/3s/disco/disco12-5-3.wav
# ./musicfile/3s/disco/disco12-5-4.wav
# ./musicfile/3s/disco/disco12-5-5.wav
# ./musicfile/3s/disco/disco12-5-6.wav
# ./musicfile/3s/disco/disco12-5-7.wav
# ./musicfile/3s/disco/disco12-5-8.wav
# ./musicfile/3s/disco/disco12-5-9.wav
# ./musicfile/3s/disco/disco12-6-0.wav
# ./musicfile/3s/disco/disco12-6-1.wav
# ./musicfile/3s/disco/disco12-6-2.wav
# ./musicfile/3s/disco/disco12-6-3.wav
# ./musicfile/3s/disco/disco12-6-4.wav
# ./musicfile/3s/disco/disco12-6-5.wav
# ./musicfile/3s/disco/disco12-6-6.wav
# ./musicfile/3s/disco/disco12-6-7.wav
# ./musicfile/3s/disco/disco12-6-8.wav
# ./musicfile/3s/disco/disco12-6-9.wav
# ./musicfile/3s/disco/disco13-1-0.wav
# ./musicfile/3s/disco/disco13-1-1.wav
# ./musicfile/3s/disco/disco13-1-2.wav
# ./musicfile/3s/disco/disco13-1-3.wav
# ./musicfile/3s/disco/disco13-1-4.wav
# ./musicfile/3s/disco/disco13-1-5.wav
# ./musicfile/3s/disco/disco13-1-6.wav
# ./musicfile/3s/disco/disco13-1-7.wav
# ./musicfile/3s/disco/disco13-1-8.wav
# ./musicfile/3s/disco/disco13-1-9.wav
# ./musicfile/3s/disco/disco13-2-0.wav
# ./musicfile/3s/disco/disco13-2-1.wav
# ./musicfile/3s/disco/disco13-2-2.wav
# ./musicfile/3s/disco/disco13-2-3.wav
# ./musicfile/3s/disco/disco13-2-4.wav
# ./musicfile/3s/disco/disco13-2-5.wav
# ./musicfile/3s/disco/disco13-2-6.wav
# ./musicfile/3s/disco/disco13-2-7.wav
# ./musicfile/3s/disco/disco13-2-8.wav
# ./musicfile/3s/disco/disco13-2-9.wav
# ./musicfile/3s/disco/disco13-3-0.wav
# ./musicfile/3s/disco/disco13-3-1.wav
# ./musicfile/3s/disco/disco13-3-2.wav
# ./musicfile/3s/disco/disco13-3-3.wav
# ./musicfile/3s/disco/disco13-3-4.wav
# ./musicfile/3s/disco/disco13-3-5.wav
# ./musicfile/3s/disco/disco13-3-6.wav
# ./musicfile/3s/disco/disco13-3-7.wav
# ./musicfile/3s/disco/disco13-3-8.wav
# ./musicfile/3s/disco/disco13-3-9.wav
# ./musicfile/3s/disco/disco13-4-0.wav
# ./musicfile/3s/disco/disco13-4-1.wav
# ./musicfile/3s/disco/disco13-4-2.wav
# ./musicfile/3s/disco/disco13-4-3.wav
# ./musicfile/3s/disco/disco13-4-4.wav
# ./musicfile/3s/disco/disco13-4-5.wav
# ./musicfile/3s/disco/disco13-4-6.wav
# ./musicfile/3s/disco/disco13-4-7.wav
# ./musicfile/3s/disco/disco13-4-8.wav
# ./musicfile/3s/disco/disco13-4-9.wav
# ./musicfile/3s/disco/disco13-5-0.wav
# ./musicfile/3s/disco/disco13-5-1.wav
# ./musicfile/3s/disco/disco13-5-2.wav
# ./musicfile/3s/disco/disco13-5-3.wav
# ./musicfile/3s/disco/disco13-5-4.wav
# ./musicfile/3s/disco/disco13-5-5.wav
# ./musicfile/3s/disco/disco13-5-6.wav
# ./musicfile/3s/disco/disco13-5-7.wav
# ./musicfile/3s/disco/disco13-5-8.wav
# ./musicfile/3s/disco/disco13-5-9.wav
# ./musicfile/3s/disco/disco13-6-0.wav
# ./musicfile/3s/disco/disco13-6-1.wav
# ./musicfile/3s/disco/disco13-6-2.wav
# ./musicfile/3s/disco/disco13-6-3.wav
# ./musicfile/3s/disco/disco13-6-4.wav
# ./musicfile/3s/disco/disco13-6-5.wav
# ./musicfile/3s/disco/disco13-6-6.wav
# ./musicfile/3s/disco/disco13-6-7.wav
# ./musicfile/3s/disco/disco13-6-8.wav
# ./musicfile/3s/disco/disco13-6-9.wav
# ./musicfile/3s/disco/disco14-1-0.wav
# ./musicfile/3s/disco/disco14-1-1.wav
# ./musicfile/3s/disco/disco14-1-2.wav
# ./musicfile/3s/disco/disco14-1-3.wav
# ./musicfile/3s/disco/disco14-1-4.wav
# ./musicfile/3s/disco/disco14-1-5.wav
# ./musicfile/3s/disco/disco14-1-6.wav
# ./musicfile/3s/disco/disco14-1-7.wav
# ./musicfile/3s/disco/disco14-1-8.wav
# ./musicfile/3s/disco/disco14-1-9.wav
# ./musicfile/3s/disco/disco14-2-0.wav
# ./musicfile/3s/disco/disco14-2-1.wav
# ./musicfile/3s/disco/disco14-2-2.wav
# ./musicfile/3s/disco/disco14-2-3.wav
# ./musicfile/3s/disco/disco14-2-4.wav
# ./musicfile/3s/disco/disco14-2-5.wav
# ./musicfile/3s/disco/disco14-2-6.wav
# ./musicfile/3s/disco/disco14-2-7.wav
# ./musicfile/3s/disco/disco14-2-8.wav
# ./musicfile/3s/disco/disco14-2-9.wav
# ./musicfile/3s/disco/disco14-3-0.wav
# ./musicfile/3s/disco/disco14-3-1.wav
# ./musicfile/3s/disco/disco14-3-2.wav
# ./musicfile/3s/disco/disco14-3-3.wav
# ./musicfile/3s/disco/disco14-3-4.wav
# ./musicfile/3s/disco/disco14-3-5.wav
# ./musicfile/3s/disco/disco14-3-6.wav
# ./musicfile/3s/disco/disco14-3-7.wav
# ./musicfile/3s/disco/disco14-3-8.wav
# ./musicfile/3s/disco/disco14-3-9.wav
# ./musicfile/3s/disco/disco14-4-0.wav
# ./musicfile/3s/disco/disco14-4-1.wav
# ./musicfile/3s/disco/disco14-4-2.wav
# ./musicfile/3s/disco/disco14-4-3.wav
# ./musicfile/3s/disco/disco14-4-4.wav
# ./musicfile/3s/disco/disco14-4-5.wav
# ./musicfile/3s/disco/disco14-4-6.wav
# ./musicfile/3s/disco/disco14-4-7.wav
# ./musicfile/3s/disco/disco14-4-8.wav
# ./musicfile/3s/disco/disco14-4-9.wav
# ./musicfile/3s/disco/disco14-5-0.wav
# ./musicfile/3s/disco/disco14-5-1.wav
# ./musicfile/3s/disco/disco14-5-2.wav
# ./musicfile/3s/disco/disco14-5-3.wav
# ./musicfile/3s/disco/disco14-5-4.wav
# ./musicfile/3s/disco/disco14-5-5.wav
# ./musicfile/3s/disco/disco14-5-6.wav
# ./musicfile/3s/disco/disco14-5-7.wav
# ./musicfile/3s/disco/disco14-5-8.wav
# ./musicfile/3s/disco/disco14-5-9.wav
# ./musicfile/3s/disco/disco15-1-0.wav
# ./musicfile/3s/disco/disco15-1-1.wav
# ./musicfile/3s/disco/disco15-1-2.wav
# ./musicfile/3s/disco/disco15-1-3.wav
# ./musicfile/3s/disco/disco15-1-4.wav
# ./musicfile/3s/disco/disco15-1-5.wav
# ./musicfile/3s/disco/disco15-1-6.wav
# ./musicfile/3s/disco/disco15-1-7.wav
# ./musicfile/3s/disco/disco15-1-8.wav
# ./musicfile/3s/disco/disco15-1-9.wav
# ./musicfile/3s/disco/disco15-2-0.wav
# ./musicfile/3s/disco/disco15-2-1.wav
# ./musicfile/3s/disco/disco15-2-2.wav
# ./musicfile/3s/disco/disco15-2-3.wav
# ./musicfile/3s/disco/disco15-2-4.wav
# ./musicfile/3s/disco/disco15-2-5.wav
# ./musicfile/3s/disco/disco15-2-6.wav
# ./musicfile/3s/disco/disco15-2-7.wav
# ./musicfile/3s/disco/disco15-2-8.wav
# ./musicfile/3s/disco/disco15-2-9.wav
# ./musicfile/3s/disco/disco15-3-0.wav
# ./musicfile/3s/disco/disco15-3-1.wav
# ./musicfile/3s/disco/disco15-3-2.wav
# ./musicfile/3s/disco/disco15-3-3.wav
# ./musicfile/3s/disco/disco15-3-4.wav
# ./musicfile/3s/disco/disco15-3-5.wav
# ./musicfile/3s/disco/disco15-3-6.wav
# ./musicfile/3s/disco/disco15-3-7.wav
# ./musicfile/3s/disco/disco15-3-8.wav
# ./musicfile/3s/disco/disco15-3-9.wav
# ./musicfile/3s/disco/disco15-4-0.wav
# ./musicfile/3s/disco/disco15-4-1.wav
# ./musicfile/3s/disco/disco15-4-2.wav
# ./musicfile/3s/disco/disco15-4-3.wav
# ./musicfile/3s/disco/disco15-4-4.wav
# ./musicfile/3s/disco/disco15-4-5.wav
# ./musicfile/3s/disco/disco15-4-6.wav
# ./musicfile/3s/disco/disco15-4-7.wav
# ./musicfile/3s/disco/disco15-4-8.wav
# ./musicfile/3s/disco/disco15-4-9.wav
# ./musicfile/3s/disco/disco15-5-0.wav
# ./musicfile/3s/disco/disco15-5-1.wav
# ./musicfile/3s/disco/disco15-5-2.wav
# ./musicfile/3s/disco/disco15-5-3.wav
# ./musicfile/3s/disco/disco15-5-4.wav
# ./musicfile/3s/disco/disco15-5-5.wav
# ./musicfile/3s/disco/disco15-5-6.wav
# ./musicfile/3s/disco/disco15-5-7.wav
# ./musicfile/3s/disco/disco15-5-8.wav
# ./musicfile/3s/disco/disco15-5-9.wav
# ./musicfile/3s/disco/disco16-1-0.wav
# ./musicfile/3s/disco/disco16-1-1.wav
# ./musicfile/3s/disco/disco16-1-2.wav
# ./musicfile/3s/disco/disco16-1-3.wav
# ./musicfile/3s/disco/disco16-1-4.wav
# ./musicfile/3s/disco/disco16-1-5.wav
# ./musicfile/3s/disco/disco16-1-6.wav
# ./musicfile/3s/disco/disco16-1-7.wav
# ./musicfile/3s/disco/disco16-1-8.wav
# ./musicfile/3s/disco/disco16-1-9.wav
# ./musicfile/3s/disco/disco16-2-0.wav
# ./musicfile/3s/disco/disco16-2-1.wav
# ./musicfile/3s/disco/disco16-2-2.wav
# ./musicfile/3s/disco/disco16-2-3.wav
# ./musicfile/3s/disco/disco16-2-4.wav
# ./musicfile/3s/disco/disco16-2-5.wav
# ./musicfile/3s/disco/disco16-2-6.wav
# ./musicfile/3s/disco/disco16-2-7.wav
# ./musicfile/3s/disco/disco16-2-8.wav
# ./musicfile/3s/disco/disco16-2-9.wav
# ./musicfile/3s/disco/disco16-3-0.wav
# ./musicfile/3s/disco/disco16-3-1.wav
# ./musicfile/3s/disco/disco16-3-2.wav
# ./musicfile/3s/disco/disco16-3-3.wav
# ./musicfile/3s/disco/disco16-3-4.wav
# ./musicfile/3s/disco/disco16-3-5.wav
# ./musicfile/3s/disco/disco16-3-6.wav
# ./musicfile/3s/disco/disco16-3-7.wav
# ./musicfile/3s/disco/disco16-3-8.wav
# ./musicfile/3s/disco/disco16-3-9.wav
# ./musicfile/3s/disco/disco16-4-0.wav
# ./musicfile/3s/disco/disco16-4-1.wav
# ./musicfile/3s/disco/disco16-4-2.wav
# ./musicfile/3s/disco/disco16-4-3.wav
# ./musicfile/3s/disco/disco16-4-4.wav
# ./musicfile/3s/disco/disco16-4-5.wav
# ./musicfile/3s/disco/disco16-4-6.wav
# ./musicfile/3s/disco/disco16-4-7.wav
# ./musicfile/3s/disco/disco16-4-8.wav
# ./musicfile/3s/disco/disco16-4-9.wav
# ./musicfile/3s/disco/disco16-5-0.wav
# ./musicfile/3s/disco/disco16-5-1.wav
# ./musicfile/3s/disco/disco16-5-2.wav
# ./musicfile/3s/disco/disco16-5-3.wav
# ./musicfile/3s/disco/disco16-5-4.wav
# ./musicfile/3s/disco/disco16-5-5.wav
# ./musicfile/3s/disco/disco16-5-6.wav
# ./musicfile/3s/disco/disco16-5-7.wav
# ./musicfile/3s/disco/disco16-5-8.wav
# ./musicfile/3s/disco/disco16-5-9.wav
# ./musicfile/3s/disco/disco16-6-0.wav
# ./musicfile/3s/disco/disco16-6-1.wav
# ./musicfile/3s/disco/disco16-6-2.wav
# ./musicfile/3s/disco/disco16-6-3.wav
# ./musicfile/3s/disco/disco16-6-4.wav
# ./musicfile/3s/disco/disco16-6-5.wav
# ./musicfile/3s/disco/disco16-6-6.wav
# ./musicfile/3s/disco/disco16-6-7.wav
# ./musicfile/3s/disco/disco16-6-8.wav
# ./musicfile/3s/disco/disco16-6-9.wav
# ./musicfile/3s/disco/disco17-1-0.wav
# ./musicfile/3s/disco/disco17-1-1.wav
# ./musicfile/3s/disco/disco17-1-2.wav
# ./musicfile/3s/disco/disco17-1-3.wav
# ./musicfile/3s/disco/disco17-1-4.wav
# ./musicfile/3s/disco/disco17-1-5.wav
# ./musicfile/3s/disco/disco17-1-6.wav
# ./musicfile/3s/disco/disco17-1-7.wav
# ./musicfile/3s/disco/disco17-1-8.wav
# ./musicfile/3s/disco/disco17-1-9.wav
# ./musicfile/3s/disco/disco17-2-0.wav
# ./musicfile/3s/disco/disco17-2-1.wav
# ./musicfile/3s/disco/disco17-2-2.wav
# ./musicfile/3s/disco/disco17-2-3.wav
# ./musicfile/3s/disco/disco17-2-4.wav
# ./musicfile/3s/disco/disco17-2-5.wav
# ./musicfile/3s/disco/disco17-2-6.wav
# ./musicfile/3s/disco/disco17-2-7.wav
# ./musicfile/3s/disco/disco17-2-8.wav
# ./musicfile/3s/disco/disco17-2-9.wav
# ./musicfile/3s/disco/disco17-3-0.wav
# ./musicfile/3s/disco/disco17-3-1.wav
# ./musicfile/3s/disco/disco17-3-2.wav
# ./musicfile/3s/disco/disco17-3-3.wav
# ./musicfile/3s/disco/disco17-3-4.wav
# ./musicfile/3s/disco/disco17-3-5.wav
# ./musicfile/3s/disco/disco17-3-6.wav
# ./musicfile/3s/disco/disco17-3-7.wav
# ./musicfile/3s/disco/disco17-3-8.wav
# ./musicfile/3s/disco/disco17-3-9.wav
# ./musicfile/3s/disco/disco17-4-0.wav
# ./musicfile/3s/disco/disco17-4-1.wav
# ./musicfile/3s/disco/disco17-4-2.wav
# ./musicfile/3s/disco/disco17-4-3.wav
# ./musicfile/3s/disco/disco17-4-4.wav
# ./musicfile/3s/disco/disco17-4-5.wav
# ./musicfile/3s/disco/disco17-4-6.wav
# ./musicfile/3s/disco/disco17-4-7.wav
# ./musicfile/3s/disco/disco17-4-8.wav
# ./musicfile/3s/disco/disco17-4-9.wav
# ./musicfile/3s/disco/disco17-5-0.wav
# ./musicfile/3s/disco/disco17-5-1.wav
# ./musicfile/3s/disco/disco17-5-2.wav
# ./musicfile/3s/disco/disco17-5-3.wav
# ./musicfile/3s/disco/disco17-5-4.wav
# ./musicfile/3s/disco/disco17-5-5.wav
# ./musicfile/3s/disco/disco17-5-6.wav
# ./musicfile/3s/disco/disco17-5-7.wav
# ./musicfile/3s/disco/disco17-5-8.wav
# ./musicfile/3s/disco/disco17-5-9.wav
# ./musicfile/3s/disco/disco17-6-0.wav
# ./musicfile/3s/disco/disco17-6-1.wav
# ./musicfile/3s/disco/disco17-6-2.wav
# ./musicfile/3s/disco/disco17-6-3.wav
# ./musicfile/3s/disco/disco17-6-4.wav
# ./musicfile/3s/disco/disco17-6-5.wav
# ./musicfile/3s/disco/disco17-6-6.wav
# ./musicfile/3s/disco/disco17-6-7.wav
# ./musicfile/3s/disco/disco17-6-8.wav
# ./musicfile/3s/disco/disco17-6-9.wav
# ./musicfile/3s/disco/disco18-1-0.wav
# ./musicfile/3s/disco/disco18-1-1.wav
# ./musicfile/3s/disco/disco18-1-2.wav
# ./musicfile/3s/disco/disco18-1-3.wav
# ./musicfile/3s/disco/disco18-1-4.wav
# ./musicfile/3s/disco/disco18-1-5.wav
# ./musicfile/3s/disco/disco18-1-6.wav
# ./musicfile/3s/disco/disco18-1-7.wav
# ./musicfile/3s/disco/disco18-1-8.wav
# ./musicfile/3s/disco/disco18-1-9.wav
# ./musicfile/3s/disco/disco18-2-0.wav
# ./musicfile/3s/disco/disco18-2-1.wav
# ./musicfile/3s/disco/disco18-2-2.wav
# ./musicfile/3s/disco/disco18-2-3.wav
# ./musicfile/3s/disco/disco18-2-4.wav
# ./musicfile/3s/disco/disco18-2-5.wav
# ./musicfile/3s/disco/disco18-2-6.wav
# ./musicfile/3s/disco/disco18-2-7.wav
# ./musicfile/3s/disco/disco18-2-8.wav
# ./musicfile/3s/disco/disco18-2-9.wav
# ./musicfile/3s/disco/disco18-3-0.wav
# ./musicfile/3s/disco/disco18-3-1.wav
# ./musicfile/3s/disco/disco18-3-2.wav
# ./musicfile/3s/disco/disco18-3-3.wav
# ./musicfile/3s/disco/disco18-3-4.wav
# ./musicfile/3s/disco/disco18-3-5.wav
# ./musicfile/3s/disco/disco18-3-6.wav
# ./musicfile/3s/disco/disco18-3-7.wav
# ./musicfile/3s/disco/disco18-3-8.wav
# ./musicfile/3s/disco/disco18-3-9.wav
# ./musicfile/3s/disco/disco18-4-0.wav
# ./musicfile/3s/disco/disco18-4-1.wav
# ./musicfile/3s/disco/disco18-4-2.wav
# ./musicfile/3s/disco/disco18-4-3.wav
# ./musicfile/3s/disco/disco18-4-4.wav
# ./musicfile/3s/disco/disco18-4-5.wav
# ./musicfile/3s/disco/disco18-4-6.wav
# ./musicfile/3s/disco/disco18-4-7.wav
# ./musicfile/3s/disco/disco18-4-8.wav
# ./musicfile/3s/disco/disco18-4-9.wav
# ./musicfile/3s/disco/disco18-5-0.wav
# ./musicfile/3s/disco/disco18-5-1.wav
# ./musicfile/3s/disco/disco18-5-2.wav
# ./musicfile/3s/disco/disco18-5-3.wav
# ./musicfile/3s/disco/disco18-5-4.wav
# ./musicfile/3s/disco/disco18-5-5.wav
# ./musicfile/3s/disco/disco18-5-6.wav
# ./musicfile/3s/disco/disco18-5-7.wav
# ./musicfile/3s/disco/disco18-5-8.wav
# ./musicfile/3s/disco/disco18-5-9.wav
# ./musicfile/3s/disco/disco18-6-0.wav
# ./musicfile/3s/disco/disco18-6-1.wav
# ./musicfile/3s/disco/disco18-6-2.wav
# ./musicfile/3s/disco/disco18-6-3.wav
# ./musicfile/3s/disco/disco18-6-4.wav
# ./musicfile/3s/disco/disco18-6-5.wav
# ./musicfile/3s/disco/disco18-6-6.wav
# ./musicfile/3s/disco/disco18-6-7.wav
# ./musicfile/3s/disco/disco18-6-8.wav
# ./musicfile/3s/disco/disco18-6-9.wav
# ./musicfile/3s/disco/disco18-7-0.wav
# ./musicfile/3s/disco/disco18-7-1.wav
# ./musicfile/3s/disco/disco18-7-2.wav
# ./musicfile/3s/disco/disco18-7-3.wav
# ./musicfile/3s/disco/disco18-7-4.wav
# ./musicfile/3s/disco/disco18-7-5.wav
# ./musicfile/3s/disco/disco18-7-6.wav
# ./musicfile/3s/disco/disco18-7-7.wav
# ./musicfile/3s/disco/disco18-7-8.wav
# ./musicfile/3s/disco/disco18-7-9.wav
# ./musicfile/3s/disco/disco19-1-0.wav
# ./musicfile/3s/disco/disco19-1-1.wav
# ./musicfile/3s/disco/disco19-1-2.wav
# ./musicfile/3s/disco/disco19-1-3.wav
# ./musicfile/3s/disco/disco19-1-4.wav
# ./musicfile/3s/disco/disco19-1-5.wav
# ./musicfile/3s/disco/disco19-1-6.wav
# ./musicfile/3s/disco/disco19-1-7.wav
# ./musicfile/3s/disco/disco19-1-8.wav
# ./musicfile/3s/disco/disco19-1-9.wav
# ./musicfile/3s/disco/disco19-2-0.wav
# ./musicfile/3s/disco/disco19-2-1.wav
# ./musicfile/3s/disco/disco19-2-2.wav
# ./musicfile/3s/disco/disco19-2-3.wav
# ./musicfile/3s/disco/disco19-2-4.wav
# ./musicfile/3s/disco/disco19-2-5.wav
# ./musicfile/3s/disco/disco19-2-6.wav
# ./musicfile/3s/disco/disco19-2-7.wav
# ./musicfile/3s/disco/disco19-2-8.wav
# ./musicfile/3s/disco/disco19-2-9.wav
# ./musicfile/3s/disco/disco19-3-0.wav
# ./musicfile/3s/disco/disco19-3-1.wav
# ./musicfile/3s/disco/disco19-3-2.wav
# ./musicfile/3s/disco/disco19-3-3.wav
# ./musicfile/3s/disco/disco19-3-4.wav
# ./musicfile/3s/disco/disco19-3-5.wav
# ./musicfile/3s/disco/disco19-3-6.wav
# ./musicfile/3s/disco/disco19-3-7.wav
# ./musicfile/3s/disco/disco19-3-8.wav
# ./musicfile/3s/disco/disco19-3-9.wav
# ./musicfile/3s/disco/disco19-4-0.wav
# ./musicfile/3s/disco/disco19-4-1.wav
# ./musicfile/3s/disco/disco19-4-2.wav
# ./musicfile/3s/disco/disco19-4-3.wav
# ./musicfile/3s/disco/disco19-4-4.wav
# ./musicfile/3s/disco/disco19-4-5.wav
# ./musicfile/3s/disco/disco19-4-6.wav
# ./musicfile/3s/disco/disco19-4-7.wav
# ./musicfile/3s/disco/disco19-4-8.wav
# ./musicfile/3s/disco/disco19-4-9.wav
# ./musicfile/3s/disco/disco19-5-0.wav
# ./musicfile/3s/disco/disco19-5-1.wav
# ./musicfile/3s/disco/disco19-5-2.wav
# ./musicfile/3s/disco/disco19-5-3.wav
# ./musicfile/3s/disco/disco19-5-4.wav
# ./musicfile/3s/disco/disco19-5-5.wav
# ./musicfile/3s/disco/disco19-5-6.wav
# ./musicfile/3s/disco/disco19-5-7.wav
# ./musicfile/3s/disco/disco19-5-8.wav
# ./musicfile/3s/disco/disco19-5-9.wav
# ./musicfile/3s/disco/disco19-6-0.wav
# ./musicfile/3s/disco/disco19-6-1.wav
# ./musicfile/3s/disco/disco19-6-2.wav
# ./musicfile/3s/disco/disco19-6-3.wav
# ./musicfile/3s/disco/disco19-6-4.wav
# ./musicfile/3s/disco/disco19-6-5.wav
# ./musicfile/3s/disco/disco19-6-6.wav
# ./musicfile/3s/disco/disco19-6-7.wav
# ./musicfile/3s/disco/disco19-6-8.wav
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\librosa\util\decorators.py:88: UserWarning: Trying to estimate tuning from empty frequency set.
#   return f(*args, **kwargs)
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\fromnumeric.py:3715: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# C:\Users\User\anaconda3\envs\python_course\lib\site-packages\numpy\core\_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ./musicfile/3s/disco/disco19-6-9.wav
# ./musicfile/3s/disco/disco2-1-0.wav
# ./musicfile/3s/disco/disco2-1-1.wav
# ./musicfile/3s/disco/disco2-1-2.wav
# ./musicfile/3s/disco/disco2-1-3.wav
# ./musicfile/3s/disco/disco2-1-4.wav
# ./musicfile/3s/disco/disco2-1-5.wav
# ./musicfile/3s/disco/disco2-1-6.wav
# ./musicfile/3s/disco/disco2-1-7.wav
# ./musicfile/3s/disco/disco2-1-8.wav
# ./musicfile/3s/disco/disco2-1-9.wav
# ./musicfile/3s/disco/disco2-2-0.wav
# ./musicfile/3s/disco/disco2-2-1.wav
# ./musicfile/3s/disco/disco2-2-2.wav
# ./musicfile/3s/disco/disco2-2-3.wav
# ./musicfile/3s/disco/disco2-2-4.wav
# ./musicfile/3s/disco/disco2-2-5.wav
# ./musicfile/3s/disco/disco2-2-6.wav
# ./musicfile/3s/disco/disco2-2-7.wav
# ./musicfile/3s/disco/disco2-2-8.wav
# ./musicfile/3s/disco/disco2-2-9.wav
# ./musicfile/3s/disco/disco2-3-0.wav
# ./musicfile/3s/disco/disco2-3-1.wav
# ./musicfile/3s/disco/disco2-3-2.wav
# ./musicfile/3s/disco/disco2-3-3.wav
# ./musicfile/3s/disco/disco2-3-4.wav
# ./musicfile/3s/disco/disco2-3-5.wav
# ./musicfile/3s/disco/disco2-3-6.wav
# ./musicfile/3s/disco/disco2-3-7.wav
# ./musicfile/3s/disco/disco2-3-8.wav
# ./musicfile/3s/disco/disco2-3-9.wav
# ./musicfile/3s/disco/disco2-4-0.wav
# ./musicfile/3s/disco/disco2-4-1.wav
# ./musicfile/3s/disco/disco2-4-2.wav
# ./musicfile/3s/disco/disco2-4-3.wav
# ./musicfile/3s/disco/disco2-4-4.wav
# ./musicfile/3s/disco/disco2-4-5.wav
# ./musicfile/3s/disco/disco2-4-6.wav
# ./musicfile/3s/disco/disco2-4-7.wav
# ./musicfile/3s/disco/disco2-4-8.wav
# ./musicfile/3s/disco/disco2-4-9.wav
# ./musicfile/3s/disco/disco2-5-0.wav
# ./musicfile/3s/disco/disco2-5-1.wav
# ./musicfile/3s/disco/disco2-5-2.wav
# ./musicfile/3s/disco/disco2-5-3.wav
# ./musicfile/3s/disco/disco2-5-4.wav
# ./musicfile/3s/disco/disco2-5-5.wav
# ./musicfile/3s/disco/disco2-5-6.wav
# ./musicfile/3s/disco/disco2-5-7.wav
# ./musicfile/3s/disco/disco2-5-8.wav
# ./musicfile/3s/disco/disco2-5-9.wav
# ./musicfile/3s/disco/disco2-6-0.wav
# ./musicfile/3s/disco/disco2-6-1.wav
# ./musicfile/3s/disco/disco2-6-2.wav
# ./musicfile/3s/disco/disco2-6-3.wav
# ./musicfile/3s/disco/disco2-6-4.wav
# ./musicfile/3s/disco/disco2-6-5.wav
# ./musicfile/3s/disco/disco2-6-6.wav
# ./musicfile/3s/disco/disco2-6-7.wav
# ./musicfile/3s/disco/disco2-6-8.wav
# ./musicfile/3s/disco/disco2-6-9.wav
# ./musicfile/3s/disco/disco2-7-0.wav
# ./musicfile/3s/disco/disco2-7-1.wav
# ./musicfile/3s/disco/disco2-7-2.wav
# ./musicfile/3s/disco/disco2-7-3.wav
# ./musicfile/3s/disco/disco2-7-4.wav
# ./musicfile/3s/disco/disco2-7-5.wav
# ./musicfile/3s/disco/disco2-7-6.wav
# ./musicfile/3s/disco/disco2-7-7.wav
# ./musicfile/3s/disco/disco2-7-8.wav
# ./musicfile/3s/disco/disco2-7-9.wav
# ./musicfile/3s/disco/disco20-1-0.wav
# ./musicfile/3s/disco/disco20-1-1.wav
# ./musicfile/3s/disco/disco20-1-2.wav
# ./musicfile/3s/disco/disco20-1-3.wav
# ./musicfile/3s/disco/disco20-1-4.wav
# ./musicfile/3s/disco/disco20-1-5.wav
# ./musicfile/3s/disco/disco20-1-6.wav
# ./musicfile/3s/disco/disco20-1-7.wav
# ./musicfile/3s/disco/disco20-1-8.wav
# ./musicfile/3s/disco/disco20-1-9.wav
# ./musicfile/3s/disco/disco20-2-0.wav
# ./musicfile/3s/disco/disco20-2-1.wav
# ./musicfile/3s/disco/disco20-2-2.wav
# ./musicfile/3s/disco/disco20-2-3.wav
# ./musicfile/3s/disco/disco20-2-4.wav
# ./musicfile/3s/disco/disco20-2-5.wav
# ./musicfile/3s/disco/disco20-2-6.wav
# ./musicfile/3s/disco/disco20-2-7.wav
# ./musicfile/3s/disco/disco20-2-8.wav
# ./musicfile/3s/disco/disco20-2-9.wav
# ./musicfile/3s/disco/disco20-3-0.wav
# ./musicfile/3s/disco/disco20-3-1.wav
# ./musicfile/3s/disco/disco20-3-2.wav
# ./musicfile/3s/disco/disco20-3-3.wav
# ./musicfile/3s/disco/disco20-3-4.wav
# ./musicfile/3s/disco/disco20-3-5.wav
# ./musicfile/3s/disco/disco20-3-6.wav
# ./musicfile/3s/disco/disco20-3-7.wav
# ./musicfile/3s/disco/disco20-3-8.wav
# ./musicfile/3s/disco/disco20-3-9.wav
# ./musicfile/3s/disco/disco20-4-0.wav
# ./musicfile/3s/disco/disco20-4-1.wav
# ./musicfile/3s/disco/disco20-4-2.wav
# ./musicfile/3s/disco/disco20-4-3.wav
# ./musicfile/3s/disco/disco20-4-4.wav
# ./musicfile/3s/disco/disco20-4-5.wav
# ./musicfile/3s/disco/disco20-4-6.wav
# ./musicfile/3s/disco/disco20-4-7.wav
# ./musicfile/3s/disco/disco20-4-8.wav
# ./musicfile/3s/disco/disco20-4-9.wav
# ./musicfile/3s/disco/disco20-5-0.wav
# ./musicfile/3s/disco/disco20-5-1.wav
# ./musicfile/3s/disco/disco20-5-2.wav
# ./musicfile/3s/disco/disco20-5-3.wav
# ./musicfile/3s/disco/disco20-5-4.wav
# ./musicfile/3s/disco/disco20-5-5.wav
# ./musicfile/3s/disco/disco20-5-6.wav
# ./musicfile/3s/disco/disco20-5-7.wav
# ./musicfile/3s/disco/disco20-5-8.wav
# ./musicfile/3s/disco/disco20-5-9.wav
# ./musicfile/3s/disco/disco20-6-0.wav
# ./musicfile/3s/disco/disco20-6-1.wav
# ./musicfile/3s/disco/disco20-6-2.wav
# ./musicfile/3s/disco/disco20-6-3.wav
# ./musicfile/3s/disco/disco20-6-4.wav
# ./musicfile/3s/disco/disco20-6-5.wav
# ./musicfile/3s/disco/disco20-6-6.wav
# ./musicfile/3s/disco/disco20-6-7.wav
# ./musicfile/3s/disco/disco20-6-8.wav
# ./musicfile/3s/disco/disco20-6-9.wav
# ./musicfile/3s/disco/disco21-1-0.wav
# ./musicfile/3s/disco/disco21-1-1.wav
# ./musicfile/3s/disco/disco21-1-2.wav
# ./musicfile/3s/disco/disco21-1-3.wav
# ./musicfile/3s/disco/disco21-1-4.wav
# ./musicfile/3s/disco/disco21-1-5.wav
# ./musicfile/3s/disco/disco21-1-6.wav
# ./musicfile/3s/disco/disco21-1-7.wav
# ./musicfile/3s/disco/disco21-1-8.wav
# ./musicfile/3s/disco/disco21-1-9.wav
# ./musicfile/3s/disco/disco21-2-0.wav
# ./musicfile/3s/disco/disco21-2-1.wav
# ./musicfile/3s/disco/disco21-2-2.wav
# ./musicfile/3s/disco/disco21-2-3.wav
# ./musicfile/3s/disco/disco21-2-4.wav
# ./musicfile/3s/disco/disco21-2-5.wav
# ./musicfile/3s/disco/disco21-2-6.wav
# ./musicfile/3s/disco/disco21-2-7.wav
# ./musicfile/3s/disco/disco21-2-8.wav
# ./musicfile/3s/disco/disco21-2-9.wav
# ./musicfile/3s/disco/disco21-3-0.wav
# ./musicfile/3s/disco/disco21-3-1.wav
# ./musicfile/3s/disco/disco21-3-2.wav
# ./musicfile/3s/disco/disco21-3-3.wav
# ./musicfile/3s/disco/disco21-3-4.wav
# ./musicfile/3s/disco/disco21-3-5.wav
# ./musicfile/3s/disco/disco21-3-6.wav
# ./musicfile/3s/disco/disco21-3-7.wav
# ./musicfile/3s/disco/disco21-3-8.wav
# ./musicfile/3s/disco/disco21-3-9.wav
# ./musicfile/3s/disco/disco21-4-0.wav
# ./musicfile/3s/disco/disco21-4-1.wav
# ./musicfile/3s/disco/disco21-4-2.wav
# ./musicfile/3s/disco/disco21-4-3.wav
# ./musicfile/3s/disco/disco21-4-4.wav
# ./musicfile/3s/disco/disco21-4-5.wav
# ./musicfile/3s/disco/disco21-4-6.wav
# ./musicfile/3s/disco/disco21-4-7.wav
# ./musicfile/3s/disco/disco21-4-8.wav
# ./musicfile/3s/disco/disco21-4-9.wav
# ./musicfile/3s/disco/disco21-5-0.wav
# ./musicfile/3s/disco/disco21-5-1.wav
# ./musicfile/3s/disco/disco21-5-2.wav
# ./musicfile/3s/disco/disco21-5-3.wav
# ./musicfile/3s/disco/disco21-5-4.wav
# ./musicfile/3s/disco/disco21-5-5.wav
# ./musicfile/3s/disco/disco21-5-6.wav
# ./musicfile/3s/disco/disco21-5-7.wav
# ./musicfile/3s/disco/disco21-5-8.wav
# ./musicfile/3s/disco/disco21-5-9.wav
# ./musicfile/3s/disco/disco21-6-0.wav
# ./musicfile/3s/disco/disco21-6-1.wav
# ./musicfile/3s/disco/disco21-6-2.wav
# ./musicfile/3s/disco/disco21-6-3.wav
# ./musicfile/3s/disco/disco21-6-4.wav
# ./musicfile/3s/disco/disco21-6-5.wav
# ./musicfile/3s/disco/disco21-6-6.wav
# ./musicfile/3s/disco/disco21-6-7.wav
# ./musicfile/3s/disco/disco21-6-8.wav
# ./musicfile/3s/disco/disco21-6-9.wav
# ./musicfile/3s/disco/disco21-7-0.wav
# ./musicfile/3s/disco/disco21-7-1.wav
# ./musicfile/3s/disco/disco21-7-2.wav
# ./musicfile/3s/disco/disco21-7-3.wav
# ./musicfile/3s/disco/disco21-7-4.wav
# ./musicfile/3s/disco/disco21-7-5.wav
# ./musicfile/3s/disco/disco21-7-6.wav
# ./musicfile/3s/disco/disco21-7-7.wav
# ./musicfile/3s/disco/disco21-7-8.wav
# ./musicfile/3s/disco/disco21-7-9.wav
# ./musicfile/3s/disco/disco22-1-0.wav
# ./musicfile/3s/disco/disco22-1-1.wav
# ./musicfile/3s/disco/disco22-1-2.wav
# ./musicfile/3s/disco/disco22-1-3.wav
# ./musicfile/3s/disco/disco22-1-4.wav
# ./musicfile/3s/disco/disco22-1-5.wav
# ./musicfile/3s/disco/disco22-1-6.wav
# ./musicfile/3s/disco/disco22-1-7.wav
# ./musicfile/3s/disco/disco22-1-8.wav
# ./musicfile/3s/disco/disco22-1-9.wav
# ./musicfile/3s/disco/disco22-2-0.wav
# ./musicfile/3s/disco/disco22-2-1.wav
# ./musicfile/3s/disco/disco22-2-2.wav
# ./musicfile/3s/disco/disco22-2-3.wav
# ./musicfile/3s/disco/disco22-2-4.wav
# ./musicfile/3s/disco/disco22-2-5.wav
# ./musicfile/3s/disco/disco22-2-6.wav
# ./musicfile/3s/disco/disco22-2-7.wav
# ./musicfile/3s/disco/disco22-2-8.wav
# ./musicfile/3s/disco/disco22-2-9.wav
# ./musicfile/3s/disco/disco22-3-0.wav
# ./musicfile/3s/disco/disco22-3-1.wav
# ./musicfile/3s/disco/disco22-3-2.wav
# ./musicfile/3s/disco/disco22-3-3.wav
# ./musicfile/3s/disco/disco22-3-4.wav
# ./musicfile/3s/disco/disco22-3-5.wav
# ./musicfile/3s/disco/disco22-3-6.wav
# ./musicfile/3s/disco/disco22-3-7.wav
# ./musicfile/3s/disco/disco22-3-8.wav
# ./musicfile/3s/disco/disco22-3-9.wav
# ./musicfile/3s/disco/disco22-4-0.wav
# ./musicfile/3s/disco/disco22-4-1.wav
# ./musicfile/3s/disco/disco22-4-2.wav
# ./musicfile/3s/disco/disco22-4-3.wav
# ./musicfile/3s/disco/disco22-4-4.wav
# ./musicfile/3s/disco/disco22-4-5.wav
# ./musicfile/3s/disco/disco22-4-6.wav
# ./musicfile/3s/disco/disco22-4-7.wav
# ./musicfile/3s/disco/disco22-4-8.wav
# ./musicfile/3s/disco/disco22-4-9.wav
# ./musicfile/3s/disco/disco22-5-0.wav
# ./musicfile/3s/disco/disco22-5-1.wav
# ./musicfile/3s/disco/disco22-5-2.wav
# ./musicfile/3s/disco/disco22-5-3.wav
# ./musicfile/3s/disco/disco22-5-4.wav
# ./musicfile/3s/disco/disco22-5-5.wav
# ./musicfile/3s/disco/disco22-5-6.wav
# ./musicfile/3s/disco/disco22-5-7.wav
# ./musicfile/3s/disco/disco22-5-8.wav
# ./musicfile/3s/disco/disco22-5-9.wav
# ./musicfile/3s/disco/disco22-6-0.wav
# ./musicfile/3s/disco/disco22-6-1.wav
# ./musicfile/3s/disco/disco22-6-2.wav
# ./musicfile/3s/disco/disco22-6-3.wav
# ./musicfile/3s/disco/disco22-6-4.wav
# ./musicfile/3s/disco/disco22-6-5.wav
# ./musicfile/3s/disco/disco22-6-6.wav
# ./musicfile/3s/disco/disco22-6-7.wav
# ./musicfile/3s/disco/disco22-6-8.wav
# ./musicfile/3s/disco/disco22-6-9.wav
# ./musicfile/3s/disco/disco23-1-0.wav
# ./musicfile/3s/disco/disco23-1-1.wav
# ./musicfile/3s/disco/disco23-1-2.wav
# ./musicfile/3s/disco/disco23-1-3.wav
# ./musicfile/3s/disco/disco23-1-4.wav
# ./musicfile/3s/disco/disco23-1-5.wav
# ./musicfile/3s/disco/disco23-1-6.wav
# ./musicfile/3s/disco/disco23-1-7.wav
# ./musicfile/3s/disco/disco23-1-8.wav
# ./musicfile/3s/disco/disco23-1-9.wav
# ./musicfile/3s/disco/disco23-2-0.wav
# ./musicfile/3s/disco/disco23-2-1.wav
# ./musicfile/3s/disco/disco23-2-2.wav
# ./musicfile/3s/disco/disco23-2-3.wav
# ./musicfile/3s/disco/disco23-2-4.wav
# ./musicfile/3s/disco/disco23-2-5.wav
# ./musicfile/3s/disco/disco23-2-6.wav
# ./musicfile/3s/disco/disco23-2-7.wav
# ./musicfile/3s/disco/disco23-2-8.wav
# ./musicfile/3s/disco/disco23-2-9.wav
# ./musicfile/3s/disco/disco23-3-0.wav
# ./musicfile/3s/disco/disco23-3-1.wav
# ./musicfile/3s/disco/disco23-3-2.wav
# ./musicfile/3s/disco/disco23-3-3.wav
# ./musicfile/3s/disco/disco23-3-4.wav
# ./musicfile/3s/disco/disco23-3-5.wav
# ./musicfile/3s/disco/disco23-3-6.wav
# ./musicfile/3s/disco/disco23-3-7.wav
# ./musicfile/3s/disco/disco23-3-8.wav
# ./musicfile/3s/disco/disco23-3-9.wav
# ./musicfile/3s/disco/disco23-4-0.wav
# ./musicfile/3s/disco/disco23-4-1.wav
# ./musicfile/3s/disco/disco23-4-2.wav
# ./musicfile/3s/disco/disco23-4-3.wav
# ./musicfile/3s/disco/disco23-4-4.wav
# ./musicfile/3s/disco/disco23-4-5.wav
# ./musicfile/3s/disco/disco23-4-6.wav
# ./musicfile/3s/disco/disco23-4-7.wav
# ./musicfile/3s/disco/disco23-4-8.wav
# ./musicfile/3s/disco/disco23-4-9.wav
# ./musicfile/3s/disco/disco23-5-0.wav
# ./musicfile/3s/disco/disco23-5-1.wav
# ./musicfile/3s/disco/disco23-5-2.wav
# ./musicfile/3s/disco/disco23-5-3.wav
# ./musicfile/3s/disco/disco23-5-4.wav
# ./musicfile/3s/disco/disco23-5-5.wav
# ./musicfile/3s/disco/disco23-5-6.wav
# ./musicfile/3s/disco/disco23-5-7.wav
# ./musicfile/3s/disco/disco23-5-8.wav
# ./musicfile/3s/disco/disco23-5-9.wav
# ./musicfile/3s/disco/disco23-6-0.wav
# ./musicfile/3s/disco/disco23-6-1.wav
# ./musicfile/3s/disco/disco23-6-2.wav
# ./musicfile/3s/disco/disco23-6-3.wav
# ./musicfile/3s/disco/disco23-6-4.wav
# ./musicfile/3s/disco/disco23-6-5.wav
# ./musicfile/3s/disco/disco23-6-6.wav
# ./musicfile/3s/disco/disco23-6-7.wav
# ./musicfile/3s/disco/disco23-6-8.wav
# ./musicfile/3s/disco/disco23-6-9.wav
# ./musicfile/3s/disco/disco24-1-0.wav
# ./musicfile/3s/disco/disco24-1-1.wav
# ./musicfile/3s/disco/disco24-1-2.wav
# ./musicfile/3s/disco/disco24-1-3.wav
# ./musicfile/3s/disco/disco24-1-4.wav
# ./musicfile/3s/disco/disco24-1-5.wav
# ./musicfile/3s/disco/disco24-1-6.wav
# ./musicfile/3s/disco/disco24-1-7.wav
# ./musicfile/3s/disco/disco24-1-8.wav
# ./musicfile/3s/disco/disco24-1-9.wav
# ./musicfile/3s/disco/disco24-10-0.wav
# ./musicfile/3s/disco/disco24-10-1.wav
# ./musicfile/3s/disco/disco24-10-2.wav
# ./musicfile/3s/disco/disco24-10-3.wav
# ./musicfile/3s/disco/disco24-10-4.wav
# ./musicfile/3s/disco/disco24-10-5.wav
# ./musicfile/3s/disco/disco24-10-6.wav
# ./musicfile/3s/disco/disco24-10-7.wav
# ./musicfile/3s/disco/disco24-10-8.wav
# ./musicfile/3s/disco/disco24-10-9.wav
# ./musicfile/3s/disco/disco24-2-0.wav
# ./musicfile/3s/disco/disco24-2-1.wav
# ./musicfile/3s/disco/disco24-2-2.wav
# ./musicfile/3s/disco/disco24-2-3.wav
# ./musicfile/3s/disco/disco24-2-4.wav
# ./musicfile/3s/disco/disco24-2-5.wav
# ./musicfile/3s/disco/disco24-2-6.wav
# ./musicfile/3s/disco/disco24-2-7.wav
# ./musicfile/3s/disco/disco24-2-8.wav
# ./musicfile/3s/disco/disco24-2-9.wav
# ./musicfile/3s/disco/disco24-3-0.wav
# ./musicfile/3s/disco/disco24-3-1.wav
# ./musicfile/3s/disco/disco24-3-2.wav
# ./musicfile/3s/disco/disco24-3-3.wav
# ./musicfile/3s/disco/disco24-3-4.wav
# ./musicfile/3s/disco/disco24-3-5.wav
# ./musicfile/3s/disco/disco24-3-6.wav
# ./musicfile/3s/disco/disco24-3-7.wav
# ./musicfile/3s/disco/disco24-3-8.wav
# ./musicfile/3s/disco/disco24-3-9.wav
# ./musicfile/3s/disco/disco24-4-0.wav
# ./musicfile/3s/disco/disco24-4-1.wav
# ./musicfile/3s/disco/disco24-4-2.wav
# ./musicfile/3s/disco/disco24-4-3.wav
# ./musicfile/3s/disco/disco24-4-4.wav
# ./musicfile/3s/disco/disco24-4-5.wav
# ./musicfile/3s/disco/disco24-4-6.wav
# ./musicfile/3s/disco/disco24-4-7.wav
# ./musicfile/3s/disco/disco24-4-8.wav
# ./musicfile/3s/disco/disco24-4-9.wav
# ./musicfile/3s/disco/disco24-5-0.wav
# ./musicfile/3s/disco/disco24-5-1.wav
# ./musicfile/3s/disco/disco24-5-2.wav
# ./musicfile/3s/disco/disco24-5-3.wav
# ./musicfile/3s/disco/disco24-5-4.wav
# ./musicfile/3s/disco/disco24-5-5.wav
# ./musicfile/3s/disco/disco24-5-6.wav
# ./musicfile/3s/disco/disco24-5-7.wav
# ./musicfile/3s/disco/disco24-5-8.wav
# ./musicfile/3s/disco/disco24-5-9.wav
# ./musicfile/3s/disco/disco24-6-0.wav
# ./musicfile/3s/disco/disco24-6-1.wav
# ./musicfile/3s/disco/disco24-6-2.wav
# ./musicfile/3s/disco/disco24-6-3.wav
# ./musicfile/3s/disco/disco24-6-4.wav
# ./musicfile/3s/disco/disco24-6-5.wav
# ./musicfile/3s/disco/disco24-6-6.wav
# ./musicfile/3s/disco/disco24-6-7.wav
# ./musicfile/3s/disco/disco24-6-8.wav
# ./musicfile/3s/disco/disco24-6-9.wav
# ./musicfile/3s/disco/disco24-7-0.wav
# ./musicfile/3s/disco/disco24-7-1.wav
# ./musicfile/3s/disco/disco24-7-2.wav
# ./musicfile/3s/disco/disco24-7-3.wav
# ./musicfile/3s/disco/disco24-7-4.wav
# ./musicfile/3s/disco/disco24-7-5.wav
# ./musicfile/3s/disco/disco24-7-6.wav
# ./musicfile/3s/disco/disco24-7-7.wav
# ./musicfile/3s/disco/disco24-7-8.wav
# ./musicfile/3s/disco/disco24-7-9.wav
# ./musicfile/3s/disco/disco24-8-0.wav
# ./musicfile/3s/disco/disco24-8-1.wav
# ./musicfile/3s/disco/disco24-8-2.wav
# ./musicfile/3s/disco/disco24-8-3.wav
# ./musicfile/3s/disco/disco24-8-4.wav
# ./musicfile/3s/disco/disco24-8-5.wav
# ./musicfile/3s/disco/disco24-8-6.wav
# ./musicfile/3s/disco/disco24-8-7.wav
# ./musicfile/3s/disco/disco24-8-8.wav
# ./musicfile/3s/disco/disco24-8-9.wav
# ./musicfile/3s/disco/disco24-9-0.wav
# ./musicfile/3s/disco/disco24-9-1.wav
# ./musicfile/3s/disco/disco24-9-2.wav
# ./musicfile/3s/disco/disco24-9-3.wav
# ./musicfile/3s/disco/disco24-9-4.wav
# ./musicfile/3s/disco/disco24-9-5.wav
# ./musicfile/3s/disco/disco24-9-6.wav
# ./musicfile/3s/disco/disco24-9-7.wav
# ./musicfile/3s/disco/disco24-9-8.wav
# ./musicfile/3s/disco/disco24-9-9.wav
# ./musicfile/3s/disco/disco25-1-0.wav
# ./musicfile/3s/disco/disco25-1-1.wav
# ./musicfile/3s/disco/disco25-1-2.wav
# ./musicfile/3s/disco/disco25-1-3.wav
# ./musicfile/3s/disco/disco25-1-4.wav
# ./musicfile/3s/disco/disco25-1-5.wav
# ./musicfile/3s/disco/disco25-1-6.wav
# ./musicfile/3s/disco/disco25-1-7.wav
# ./musicfile/3s/disco/disco25-1-8.wav
# ./musicfile/3s/disco/disco25-1-9.wav
# ./musicfile/3s/disco/disco25-2-0.wav
# ./musicfile/3s/disco/disco25-2-1.wav
# ./musicfile/3s/disco/disco25-2-2.wav
# ./musicfile/3s/disco/disco25-2-3.wav
# ./musicfile/3s/disco/disco25-2-4.wav
# ./musicfile/3s/disco/disco25-2-5.wav
# ./musicfile/3s/disco/disco25-2-6.wav
# ./musicfile/3s/disco/disco25-2-7.wav
# ./musicfile/3s/disco/disco25-2-8.wav
# ./musicfile/3s/disco/disco25-2-9.wav
# ./musicfile/3s/disco/disco25-3-0.wav
# ./musicfile/3s/disco/disco25-3-1.wav
# ./musicfile/3s/disco/disco25-3-2.wav
# ./musicfile/3s/disco/disco25-3-3.wav
# ./musicfile/3s/disco/disco25-3-4.wav
# ./musicfile/3s/disco/disco25-3-5.wav
# ./musicfile/3s/disco/disco25-3-6.wav
# ./musicfile/3s/disco/disco25-3-7.wav
# ./musicfile/3s/disco/disco25-3-8.wav
# ./musicfile/3s/disco/disco25-3-9.wav
# ./musicfile/3s/disco/disco25-4-0.wav
# ./musicfile/3s/disco/disco25-4-1.wav
# ./musicfile/3s/disco/disco25-4-2.wav
# ./musicfile/3s/disco/disco25-4-3.wav
# ./musicfile/3s/disco/disco25-4-4.wav
# ./musicfile/3s/disco/disco25-4-5.wav
# ./musicfile/3s/disco/disco25-4-6.wav
# ./musicfile/3s/disco/disco25-4-7.wav
# ./musicfile/3s/disco/disco25-4-8.wav
# ./musicfile/3s/disco/disco25-4-9.wav
# ./musicfile/3s/disco/disco25-5-0.wav
# ./musicfile/3s/disco/disco25-5-1.wav
# ./musicfile/3s/disco/disco25-5-2.wav
# ./musicfile/3s/disco/disco25-5-3.wav
# ./musicfile/3s/disco/disco25-5-4.wav
# ./musicfile/3s/disco/disco25-5-5.wav
# ./musicfile/3s/disco/disco25-5-6.wav
# ./musicfile/3s/disco/disco25-5-7.wav
# ./musicfile/3s/disco/disco25-5-8.wav
# ./musicfile/3s/disco/disco25-5-9.wav
# ./musicfile/3s/disco/disco25-6-0.wav
# ./musicfile/3s/disco/disco25-6-1.wav
# ./musicfile/3s/disco/disco25-6-2.wav
# ./musicfile/3s/disco/disco25-6-3.wav
# ./musicfile/3s/disco/disco25-6-4.wav
# ./musicfile/3s/disco/disco25-6-5.wav
# ./musicfile/3s/disco/disco25-6-6.wav
# ./musicfile/3s/disco/disco25-6-7.wav
# ./musicfile/3s/disco/disco25-6-8.wav
# ./musicfile/3s/disco/disco25-6-9.wav
# ./musicfile/3s/disco/disco25-7-0.wav
# ./musicfile/3s/disco/disco25-7-1.wav
# ./musicfile/3s/disco/disco25-7-2.wav
# ./musicfile/3s/disco/disco25-7-3.wav
# ./musicfile/3s/disco/disco25-7-4.wav
# ./musicfile/3s/disco/disco25-7-5.wav
# ./musicfile/3s/disco/disco25-7-6.wav
# ./musicfile/3s/disco/disco25-7-7.wav
# ./musicfile/3s/disco/disco25-7-8.wav
# ./musicfile/3s/disco/disco25-7-9.wav
# ./musicfile/3s/disco/disco25-8-0.wav
# ./musicfile/3s/disco/disco25-8-1.wav
# ./musicfile/3s/disco/disco25-8-2.wav
# ./musicfile/3s/disco/disco25-8-3.wav
# ./musicfile/3s/disco/disco25-8-4.wav
# ./musicfile/3s/disco/disco25-8-5.wav
# ./musicfile/3s/disco/disco25-8-6.wav
# ./musicfile/3s/disco/disco25-8-7.wav
# ./musicfile/3s/disco/disco25-8-8.wav
# ./musicfile/3s/disco/disco25-8-9.wav
# ./musicfile/3s/disco/disco25-9-0.wav
# ./musicfile/3s/disco/disco25-9-1.wav
# ./musicfile/3s/disco/disco25-9-2.wav
# ./musicfile/3s/disco/disco25-9-3.wav
# ./musicfile/3s/disco/disco25-9-4.wav
# ./musicfile/3s/disco/disco25-9-5.wav
# ./musicfile/3s/disco/disco25-9-6.wav
# ./musicfile/3s/disco/disco25-9-7.wav
# ./musicfile/3s/disco/disco25-9-8.wav
# ./musicfile/3s/disco/disco25-9-9.wav
# ./musicfile/3s/disco/disco26-1-0.wav
# ./musicfile/3s/disco/disco26-1-1.wav
# ./musicfile/3s/disco/disco26-1-2.wav
# ./musicfile/3s/disco/disco26-1-3.wav
# ./musicfile/3s/disco/disco26-1-4.wav
# ./musicfile/3s/disco/disco26-1-5.wav
# ./musicfile/3s/disco/disco26-1-6.wav
# ./musicfile/3s/disco/disco26-1-7.wav
# ./musicfile/3s/disco/disco26-1-8.wav
# ./musicfile/3s/disco/disco26-1-9.wav
# ./musicfile/3s/disco/disco26-2-0.wav
# ./musicfile/3s/disco/disco26-2-1.wav
# ./musicfile/3s/disco/disco26-2-2.wav
# ./musicfile/3s/disco/disco26-2-3.wav
# ./musicfile/3s/disco/disco26-2-4.wav
# ./musicfile/3s/disco/disco26-2-5.wav
# ./musicfile/3s/disco/disco26-2-6.wav
# ./musicfile/3s/disco/disco26-2-7.wav
# ./musicfile/3s/disco/disco26-2-8.wav
# ./musicfile/3s/disco/disco26-2-9.wav
# ./musicfile/3s/disco/disco26-3-0.wav
# ./musicfile/3s/disco/disco26-3-1.wav
# ./musicfile/3s/disco/disco26-3-2.wav
# ./musicfile/3s/disco/disco26-3-3.wav
# ./musicfile/3s/disco/disco26-3-4.wav
# ./musicfile/3s/disco/disco26-3-5.wav
# ./musicfile/3s/disco/disco26-3-6.wav
# ./musicfile/3s/disco/disco26-3-7.wav
# ./musicfile/3s/disco/disco26-3-8.wav
# ./musicfile/3s/disco/disco26-3-9.wav
# ./musicfile/3s/disco/disco26-4-0.wav
# ./musicfile/3s/disco/disco26-4-1.wav
# ./musicfile/3s/disco/disco26-4-2.wav
# ./musicfile/3s/disco/disco26-4-3.wav
# ./musicfile/3s/disco/disco26-4-4.wav
# ./musicfile/3s/disco/disco26-4-5.wav
# ./musicfile/3s/disco/disco26-4-6.wav
# ./musicfile/3s/disco/disco26-4-7.wav
# ./musicfile/3s/disco/disco26-4-8.wav
# ./musicfile/3s/disco/disco26-4-9.wav
# ./musicfile/3s/disco/disco26-5-0.wav
# ./musicfile/3s/disco/disco26-5-1.wav
# ./musicfile/3s/disco/disco26-5-2.wav
# ./musicfile/3s/disco/disco26-5-3.wav
# ./musicfile/3s/disco/disco26-5-4.wav
# ./musicfile/3s/disco/disco26-5-5.wav
# ./musicfile/3s/disco/disco26-5-6.wav
# ./musicfile/3s/disco/disco26-5-7.wav
# ./musicfile/3s/disco/disco26-5-8.wav
# ./musicfile/3s/disco/disco26-5-9.wav
# ./musicfile/3s/disco/disco26-6-0.wav
# ./musicfile/3s/disco/disco26-6-1.wav
# ./musicfile/3s/disco/disco26-6-2.wav
# ...
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:563: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc13_delta_var'] = mfcc13_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:564: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc14_delta_var'] = mfcc14_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:565: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc15_delta_var'] = mfcc15_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc16_delta_var'] = mfcc16_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:567: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc17_delta_var'] = mfcc17_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:568: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc18_delta_var'] = mfcc18_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:569: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc19_delta_var'] = mfcc19_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:570: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['mfcc20_delta_var'] = mfcc20_delta_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['rmse_mean'] = rmse_mean  # rmse
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:573: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['rmse_std'] = rmse_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:574: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['rmse_var'] = rmse_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:575: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['cent_mean'] = cent_mean  # cent
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:576: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['cent_std'] = cent_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:577: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['cent_var'] = cent_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:578: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['spec_bw_mean'] = spec_bw_mean  # spectral bandwidth
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:579: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['spec_bw_std'] = spec_bw_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:580: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['spec_bw_var'] = spec_bw_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:581: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['contrast_mean'] = contrast_mean  # contrast
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:582: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['contrast_std'] = contrast_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:583: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['contrast_var'] = contrast_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:584: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['rolloff_mean'] = rolloff_mean  # rolloff
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:585: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['rolloff_std'] = rolloff_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:586: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['rolloff_var'] = rolloff_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:587: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['poly_mean'] = poly_mean  # poly features
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:588: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['poly_std'] = poly_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:589: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['poly_var'] = poly_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:590: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['tonnetz_mean'] = tonnetz_mean  # tonnetz
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:591: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['tonnetz_std'] = tonnetz_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:592: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['tonnetz_var'] = tonnetz_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:593: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['zcr_mean'] = zcr_mean  # zero crossing rate
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:594: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['zcr_std'] = zcr_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:595: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['zcr_var'] = zcr_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:596: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['harm_mean'] = harm_mean  # harmonic
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:597: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['harm_std'] = harm_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:598: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['harm_var'] = harm_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:599: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['perc_mean'] = perc_mean  # percussive
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:600: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['perc_std'] = perc_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:601: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['perc_var'] = perc_var
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:602: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['frame_mean'] = frame_mean  # frames
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:603: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['frame_std'] = frame_std
# C:\Users\User\AppData\Local\Temp\ipykernel_5848\84421555.py:604: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feature_set['frame_var'] = frame_var
# This time is being calculated
# 3863.330346999999
